# %% [markdown]
# # EV Behaviour Rep

# %%
# %matplotlib notebook
import numpy as np
from scipy.stats import genexpon
import matplotlib.pyplot as plt
from numpy.random import RandomState
import pandas as pd

# %% [markdown]
# # Commercial Feeder EV Arrival and Departure statistics

# %% [markdown]
# #Morning Arrival Commercial Feeders

# %%
from scipy.stats import genextreme

genloc=8.9068    #Shift
genscale=0.5492  #Scale
genc=0.0629  #Shape

x = np.linspace(genextreme.ppf(0.01, genc,loc=genloc,scale=genscale),
                genextreme.ppf(0.99, genc,loc=genloc,scale=genscale), 100)

genvalmarr = genextreme.rvs(genc, loc = genloc, scale=genscale, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x, genextreme.pdf(x, genc,loc=genloc,scale=genscale),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalmarr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='e2a0c169-2628-42a2-86bc-4084b651d468'></div>
# <div id='962e171a-9214-4a72-8c97-846e4d5c516c'></div>

# %%
plt.figure()
plt.plot(genvalmarr)
plt.show()
# Out:
# <div id='8ba6a5e8-194f-494d-b980-a9beb1600648'></div>

# %% [markdown]
# Evening departure Commercial feeders

# %%
from scipy.stats import genextreme

genloc1= 16.4070    #Shift
genscale1= 1.1106 #Scale
genc1= -0.2821 #Shape

x1 = np.linspace(genextreme.ppf(0.01, genc1 ,loc=genloc1 ,scale=genscale1),
                genextreme.ppf(0.99, genc1 ,loc=genloc1,scale=genscale1), 100)

genvalevdep = genextreme.rvs(genc1, loc = genloc1, scale=genscale1, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x1, genextreme.pdf(x1, genc1,loc=genloc1,scale=genscale1),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalevdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='e66f4468-e34e-4fdd-aecc-76f570e2cab5'></div>
# <div id='019299fe-8ac1-47fe-abc8-66d3ac4500bd'></div>

# %%
plt.figure()
plt.plot(genvalevdep)
plt.show()
# Out:
# <div id='42261fd6-c1b3-4fd3-ab09-abfd182434bb'></div>

# %%
import seaborn as sns
sns.boxplot(genvalevdep)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# Limit Data
result=[]
for val in genvalevdep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalevdep
genvalevdep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x1, genextreme.pdf(x1, genc1,loc=genloc1,scale=genscale1),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalevdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='f5babd48-79c7-49fe-b83a-4823c084c022'></div>
# <div id='bbc69260-d96d-4fcf-a8a7-c7c85647a584'></div>

# %%
plt.figure()
plt.plot(genvalevdep)
plt.show()
# Out:
# <div id='072608bc-73ca-4972-ac10-7a376a9a3bdb'></div>

# %% [markdown]
# Night departure Commerical feeders

# %%
from scipy.stats import genextreme

genloc2= 20.5495    #Shift 20.5495
genscale2= 0.5369 #Scale 0.5369
genc2= -0.2779 #Shape -0.2779

x2 = np.linspace(genextreme.ppf(0.01, genc2 ,loc=genloc2 ,scale=genscale2),
                genextreme.ppf(0.99, genc2 ,loc=genloc2,scale=genscale2), 100)

genvalngdep = genextreme.rvs(genc2, loc = genloc2, scale=genscale2, size=8761)

# %%
result=[]
for val in genvalngdep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalngdep
genvalngdep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x2, genextreme.pdf(x2, genc2,loc=genloc2,scale=genscale2),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalngdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='eacee283-fad6-45c0-ac75-0dd40ac18b32'></div>
# <div id='4936c0c2-a6e3-46fe-8a70-4f0a4882d930'></div>

# %%
plt.figure()
plt.plot(genvalngdep)
plt.show()
# Out:
# <div id='d6ffe811-4515-4d51-b7a8-700a366f38db'></div>

# %% [markdown]
# Evening Arrivals Commercial feeders

# %%
from scipy.stats import weibull_min

genscale3= 16.0386 #Scale 16.0386 
genc3=18.0225  #Shape 18.0225
x3 = np.linspace(weibull_min.ppf(0.01, genc3 ,scale=genscale3),
                weibull_min.ppf(0.99, genc3 ,scale=genscale3), 100)

WeibullValEvnArr = weibull_min.rvs(genc3, scale=genscale3, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x3, weibull_min.pdf(x3, genc3,scale=genscale3),
       'r-', lw=5, alpha=0.6, label='Weibull pdf')
ax.hist(WeibullValEvnArr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='ab84471c-4d5b-4429-82e9-17b45c23dd93'></div>
# <div id='48e07954-e36a-4f4a-bd6d-c00abef01bc1'></div>

# %%
plt.figure()
plt.plot(WeibullValEvnArr)
plt.show()
# Out:
# <div id='d491c9f7-c2d3-4b4c-9682-b0ed7bbedbd3'></div>

# %% [markdown]
# # Residential feeder EV Arrival and Departure statistics

# %% [markdown]
# Evening Arrival Residentail feeder

# %%
from scipy.stats import genextreme

genloc4= 13.7393    #Shift
genscale4= 0.5129 #Scale
genc4= 0.0631 #Shape

x4 = np.linspace(genextreme.ppf(0.01, genc4 ,loc=genloc4 ,scale=genscale4),
                genextreme.ppf(0.99, genc4 ,loc=genloc4,scale=genscale4), 100)

genvalEvArr = genextreme.rvs(genc4, loc = genloc4, scale=genscale4, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x4, genextreme.pdf(x4, genc4,loc=genloc4,scale=genscale4),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalEvArr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='bafef978-cba7-4d66-bec3-14ce0226e697'></div>
# <div id='0155c76a-b691-40d4-9755-4ae5a36343ba'></div>

# %%
plt.figure()
plt.plot(genvalEvArr)
plt.show()
# Out:
# <div id='99d97e22-04f8-4af4-8894-8002cc07e3d4'></div>

# %% [markdown]
# Morning Departure Residential feedeer

# %%
from scipy.stats import genextreme

genloc5= 7.0910   #Shift
genscale5= 1.1832 #Scale
genc5= -0.2532 #Shape

x5 = np.linspace(genextreme.ppf(0.01, genc5 ,loc=genloc5 ,scale=genscale5),
                genextreme.ppf(0.99, genc5 ,loc=genloc5,scale=genscale5), 100)

genvalRmordep = genextreme.rvs(genc5, loc = genloc5, scale=genscale5, size=8761)

# %%
result=[]
for val in genvalRmordep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalRmordep
genvalRmordep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x5, genextreme.pdf(x5, genc5,loc=genloc5,scale=genscale5),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalRmordep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='f746c064-876b-41c6-b99e-566867647f0d'></div>
# <div id='eb674126-1f10-414f-bcdb-736d803c88af'></div>

# %%
plt.figure()
plt.plot(genvalRmordep)
plt.show()
# Out:
# <ipython-input-25-bda56d139d91>:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <div id='689d99b8-78b2-479c-849a-8b98ce490eab'></div>

# %% [markdown]
# # commercial and residential feeder travelled Distance

# %%
from scipy.stats import genextreme

genloc6= 15.8820
genscale6= 7.9015 
genc6= 0.00474

x6 = np.linspace(genextreme.ppf(0.01, genc6 ,loc=genloc6 ,scale=genscale6),
                genextreme.ppf(0.99, genc6 ,loc=genloc6,scale=genscale6), 100)

genvalDistance= genextreme.rvs(genc6, loc = genloc6, scale=genscale6, size=8761)
#genvalDistance=pd.Series((genvalDistance/1.609))
#genvalDistance=genvalDistance.round(decimals=2)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x6, genextreme.pdf(x6, genc6,loc=genloc6,scale=genscale6),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalDistance, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='4d9140e2-ada7-44a0-b014-421985a4a737'></div>
# <div id='a3bc5bee-05fb-4c40-ad4d-036e7a24a3e2'></div>

# %%
plt.figure()
plt.plot(genvalDistance)
plt.show()
# Out:
# <div id='67bb6db6-3e17-4bf3-89c9-5c4887891bf9'></div>

# %%
import datetime

result=[]

for val in genvalmarr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalmarr
genvalmarr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalevdep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalevdep
genvalevdep=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalngdep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalngdep
genvalngdep=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in WeibullValEvnArr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del WeibullValEvnArr
WeibullValEvnArr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalEvArr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalEvArr
genvalEvArr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalRmordep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalRmordep
genvalRmordep=pd.to_datetime(result, format='%H:%M:%S.%f').time

# %%
df=pd.DataFrame({'Commercial Morning Arrival': genvalmarr,
                 'Commercial Evening Departure': genvalevdep,
                 'Commercial Night Departure': genvalngdep,
                 'Commercial Evening Arrival': WeibullValEvnArr,
                 'Residential Evening Arrival': genvalEvArr,
                 'Residential Morning Departure': genvalRmordep,
                 'Travelled distance': genvalDistance,
                 #'SOCi':Socinitial,  
                })
df
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:47:30.616298              18:13:02.778154
# 1               09:36:51.531057              23:00:00.036000
# 2               08:48:34.676240              17:19:08.527339
# 3               08:23:25.554890              16:13:39.845129
# 4               08:38:32.232027              16:06:30.784198
# ...                         ...                          ...
# 8756            08:57:01.733798              15:55:36.133862
# 8757            08:17:35.527239              15:32:48.027180
# 8758            09:16:10.198706              18:34:05.317121
# 8759            08:37:17.038117              15:23:58.155274
# 8760            11:09:07.815202              16:16:42.263847
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:38:52.080047            17:53:53.427742
# 1               20:10:19.039272            15:38:34.096205
# 2               20:53:50.245552            14:45:00.200717
# 3               19:50:43.053470            16:11:00.263753
# 4               20:12:08.775994            15:10:44.698985
# ...                         ...                        ...
# 8756            20:30:21.342555            16:08:50.808838
# 8757            22:27:20.900498            16:45:56.637893
# 8758            20:31:06.054380            16:15:15.554871
# 8759            20:12:38.371584            14:58:08.904512
# 8760            23:12:42.965486            15:59:13.261934
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                14:19:26.130443               06:21:36.230535
# 1                14:49:15.267049               06:45:16.101426
# 2                13:35:07.160630               07:54:00.702078
# 3                13:51:33.812598               09:24:57.709057
# 4                14:35:19.206656               08:07:59.701619
# ...                          ...                           ...
# 8756             13:18:23.040514               10:48:54.382843
# 8757             13:28:32.331945               06:49:30.565887
# 8758             13:34:15.143999               06:51:06.561406
# 8759             14:28:24.884025               07:00:59.426498
# 8760             14:13:54.720069               08:57:25.479790
#
#       Travelled distance
# 0              43.072703
# 1              14.498635
# 2              19.018282
# 3              17.870129
# 4               9.802032
# ...                  ...
# 8756           25.600789
# 8757           22.667008
# 8758           19.874952
# 8759            9.128183
# 8760           18.743991
#
# [8761 rows x 7 columns]

# %%
#df.to_excel('EVbehaviour.xlsx', engine='xlsxwriter')
df.to_excel('EVbehaviour.xlsx')

# %%
print(df)
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:47:30.616298              18:13:02.778154
# 1               09:36:51.531057              23:00:00.036000
# 2               08:48:34.676240              17:19:08.527339
# 3               08:23:25.554890              16:13:39.845129
# 4               08:38:32.232027              16:06:30.784198
# ...                         ...                          ...
# 8756            08:57:01.733798              15:55:36.133862
# 8757            08:17:35.527239              15:32:48.027180
# 8758            09:16:10.198706              18:34:05.317121
# 8759            08:37:17.038117              15:23:58.155274
# 8760            11:09:07.815202              16:16:42.263847
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:38:52.080047            17:53:53.427742
# 1               20:10:19.039272            15:38:34.096205
# 2               20:53:50.245552            14:45:00.200717
# 3               19:50:43.053470            16:11:00.263753
# 4               20:12:08.775994            15:10:44.698985
# ...                         ...                        ...
# 8756            20:30:21.342555            16:08:50.808838
# 8757            22:27:20.900498            16:45:56.637893
# 8758            20:31:06.054380            16:15:15.554871
# 8759            20:12:38.371584            14:58:08.904512
# 8760            23:12:42.965486            15:59:13.261934
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                14:19:26.130443               06:21:36.230535
# 1                14:49:15.267049               06:45:16.101426
# 2                13:35:07.160630               07:54:00.702078
# 3                13:51:33.812598               09:24:57.709057
# 4                14:35:19.206656               08:07:59.701619
# ...                          ...                           ...
# 8756             13:18:23.040514               10:48:54.382843
# 8757             13:28:32.331945               06:49:30.565887
# 8758             13:34:15.143999               06:51:06.561406
# 8759             14:28:24.884025               07:00:59.426498
# 8760             14:13:54.720069               08:57:25.479790
#
#       Travelled distance
# 0              43.072703
# 1              14.498635
# 2              19.018282
# 3              17.870129
# 4               9.802032
# ...                  ...
# 8756           25.600789
# 8757           22.667008
# 8758           19.874952
# 8759            9.128183
# 8760           18.743991
#
# [8761 rows x 7 columns]

# %% [markdown]
# # Merge PowerTrain Simulations with Probability Data

# %%
dfv=pd.read_excel('(BEV) Full Discharge 2016 Nissan Leaf 30 kWh UDDS.xlsx',index_col=0)
dfv['distance']=dfv['distance']*1.609
maxEnergy=dfv.essCurKwh[0]
del dfv['mpsAch']
del dfv['essKwOutAch']
del dfv['speed']

# %%
dfv['ChgEnergyReq']=maxEnergy-dfv['essCurKwh']
dfv
# Out:
#             soc  essCurKwh    distance  ChgEnergyReq
# 0      0.950000  28.500000    0.000000      0.000000
# 1      0.949998  28.499929    0.000000      0.000071
# 2      0.949995  28.499859    0.000000      0.000141
# 3      0.949993  28.499788    0.000000      0.000212
# 4      0.949991  28.499718    0.000000      0.000282
# ...         ...        ...         ...           ...
# 30539  0.050081   1.502425  268.562905     26.997575
# 30540  0.050078   1.502354  268.562905     26.997646
# 30541  0.050076   1.502284  268.562905     26.997716
# 30542  0.050074   1.502213  268.562905     26.997787
# 30543  0.050058   1.501737  268.564067     26.998263
#
# [30427 rows x 4 columns]

# %% [raw]
# .sub(search_value) subtracts search_value from the df[col_to_search] to make the nearest value almost-zero,
# .abs() makes the almost-zero the minimum of the column,
# .idxmin() yields the df.index of the minimum value, or the closest match to search_value.

# %%
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfv['distance'].sub(x).abs().idxmin())

# %%
dfv=dfv.loc[tempind]
dfv=dfv.reset_index()
del dfv['index']

# %%
df['Travelled distance']
# Out:
# 0       43.072703
# 1       14.498635
# 2       19.018282
# 3       17.870129
# 4        9.802032
#           ...
# 8756    25.600789
# 8757    22.667008
# 8758    19.874952
# 8759     9.128183
# 8760    18.743991
# Name: Travelled distance, Length: 8761, dtype: float64

# %%
dfv
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.802025  24.060746  43.069562      4.439254
# 1     0.895556  26.866670  14.503895      1.633330
# 2     0.883585  26.507538  19.015739      1.992462
# 3     0.886661  26.599843  17.870425      1.900157
# 4     0.915819  27.474576   9.798567      1.025424
# ...        ...        ...        ...           ...
# 8756  0.860812  25.824369  25.601214      2.675631
# 8757  0.872551  26.176538  22.672697      2.323462
# 8758  0.879644  26.389314  19.882289      2.110686
# 8759  0.917685  27.530562   9.129927      0.969438
# 8760  0.884183  26.525489  18.743947      1.974511
#
# [8761 rows x 4 columns]

# %%
dfmega=df.join(dfv)
#del dfmega['SOCi']

# %%
dfmega
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:47:30.616298              18:13:02.778154
# 1               09:36:51.531057              23:00:00.036000
# 2               08:48:34.676240              17:19:08.527339
# 3               08:23:25.554890              16:13:39.845129
# 4               08:38:32.232027              16:06:30.784198
# ...                         ...                          ...
# 8756            08:57:01.733798              15:55:36.133862
# 8757            08:17:35.527239              15:32:48.027180
# 8758            09:16:10.198706              18:34:05.317121
# 8759            08:37:17.038117              15:23:58.155274
# 8760            11:09:07.815202              16:16:42.263847
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:38:52.080047            17:53:53.427742
# 1               20:10:19.039272            15:38:34.096205
# 2               20:53:50.245552            14:45:00.200717
# 3               19:50:43.053470            16:11:00.263753
# 4               20:12:08.775994            15:10:44.698985
# ...                         ...                        ...
# 8756            20:30:21.342555            16:08:50.808838
# 8757            22:27:20.900498            16:45:56.637893
# 8758            20:31:06.054380            16:15:15.554871
# 8759            20:12:38.371584            14:58:08.904512
# 8760            23:12:42.965486            15:59:13.261934
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                14:19:26.130443               06:21:36.230535
# 1                14:49:15.267049               06:45:16.101426
# 2                13:35:07.160630               07:54:00.702078
# 3                13:51:33.812598               09:24:57.709057
# 4                14:35:19.206656               08:07:59.701619
# ...                          ...                           ...
# 8756             13:18:23.040514               10:48:54.382843
# 8757             13:28:32.331945               06:49:30.565887
# 8758             13:34:15.143999               06:51:06.561406
# 8759             14:28:24.884025               07:00:59.426498
# 8760             14:13:54.720069               08:57:25.479790
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              43.072703  0.802025  24.060746  43.069562      4.439254
# 1              14.498635  0.895556  26.866670  14.503895      1.633330
# 2              19.018282  0.883585  26.507538  19.015739      1.992462
# 3              17.870129  0.886661  26.599843  17.870425      1.900157
# 4               9.802032  0.915819  27.474576   9.798567      1.025424
# ...                  ...       ...        ...        ...           ...
# 8756           25.600789  0.860812  25.824369  25.601214      2.675631
# 8757           22.667008  0.872551  26.176538  22.672697      2.323462
# 8758           19.874952  0.879644  26.389314  19.882289      2.110686
# 8759            9.128183  0.917685  27.530562   9.129927      0.969438
# 8760           18.743991  0.884183  26.525489  18.743947      1.974511
#
# [8761 rows x 11 columns]

# %%
dfmega.tail
# Out:
# <bound method NDFrame.tail of      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:47:30.616298              18:13:02.778154
# 1               09:36:51.531057              23:00:00.036000
# 2               08:48:34.676240              17:19:08.527339
# 3               08:23:25.554890              16:13:39.845129
# 4               08:38:32.232027              16:06:30.784198
# ...                         ...                          ...
# 8756            08:57:01.733798              15:55:36.133862
# 8757            08:17:35.527239              15:32:48.027180
# 8758            09:16:10.198706              18:34:05.317121
# 8759            08:37:17.038117              15:23:58.155274
# 8760            11:09:07.815202              16:16:42.263847
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:38:52.080047            17:53:53.427742
# 1               20:10:19.039272            15:38:34.096205
# 2               20:53:50.245552            14:45:00.200717
# 3               19:50:43.053470            16:11:00.263753
# 4               20:12:08.775994            15:10:44.698985
# ...                         ...                        ...
# 8756            20:30:21.342555            16:08:50.808838
# 8757            22:27:20.900498            16:45:56.637893
# 8758            20:31:06.054380            16:15:15.554871
# 8759            20:12:38.371584            14:58:08.904512
# 8760            23:12:42.965486            15:59:13.261934
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                14:19:26.130443               06:21:36.230535
# 1                14:49:15.267049               06:45:16.101426
# 2                13:35:07.160630               07:54:00.702078
# 3                13:51:33.812598               09:24:57.709057
# 4                14:35:19.206656               08:07:59.701619
# ...                          ...                           ...
# 8756             13:18:23.040514               10:48:54.382843
# 8757             13:28:32.331945               06:49:30.565887
# 8758             13:34:15.143999               06:51:06.561406
# 8759             14:28:24.884025               07:00:59.426498
# 8760             14:13:54.720069               08:57:25.479790
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              43.072703  0.802025  24.060746  43.069562      4.439254
# 1              14.498635  0.895556  26.866670  14.503895      1.633330
# 2              19.018282  0.883585  26.507538  19.015739      1.992462
# 3              17.870129  0.886661  26.599843  17.870425      1.900157
# 4               9.802032  0.915819  27.474576   9.798567      1.025424
# ...                  ...       ...        ...        ...           ...
# 8756           25.600789  0.860812  25.824369  25.601214      2.675631
# 8757           22.667008  0.872551  26.176538  22.672697      2.323462
# 8758           19.874952  0.879644  26.389314  19.882289      2.110686
# 8759            9.128183  0.917685  27.530562   9.129927      0.969438
# 8760           18.743991  0.884183  26.525489  18.743947      1.974511
#
# [8761 rows x 11 columns]>

# %% [markdown]
# Merging Power train Simulations with probability data for PHEVs prius 2017

# %%
dfhv=pd.read_excel('(PHEV) Full Discharge 2017 Prius Prime UDDS.xlsx',index_col=0)
dfhv['distance']=dfhv['distance']*6.00
maxEnergy=dfhv.essCurKwh[0]
del dfhv['mpsAch']
del dfhv['essKwOutAch']
del dfhv['speed']

# %%
dfhv['ChgEnergyReq']=maxEnergy-dfhv['essCurKwh']
dfhv
# Out:
#             soc  essCurKwh     distance  ChgEnergyReq
# 0      0.900000   7.920000     0.000000      0.000000
# 1      0.899990   7.919915     0.000000      0.000085
# 2      0.899981   7.919831     0.000000      0.000169
# 3      0.899971   7.919746     0.000000      0.000254
# 4      0.899962   7.919662     0.000000      0.000338
# ...         ...        ...          ...           ...
# 87675  0.270340   2.378995  2860.991583      5.541005
# 87676  0.270455   2.380006  2860.995750      5.539994
# 87677  0.270484   2.380256  2860.995750      5.539744
# 87678  0.270502   2.380414  2860.995750      5.539586
# 87679  0.270520   2.380572  2860.995750      5.539428
#
# [87680 rows x 4 columns]

# %%
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfhv['distance'].sub(x).abs().idxmin())

# %%
dfhv=dfhv.loc[tempind]
dfhv=dfhv.reset_index()
del dfhv['index']

# %%
df['Travelled distance']
# Out:
# 0       43.072703
# 1       14.498635
# 2       19.018282
# 3       17.870129
# 4        9.802032
#           ...
# 8756    25.600789
# 8757    22.667008
# 8758    19.874952
# 8759     9.128183
# 8760    18.743991
# Name: Travelled distance, Length: 8761, dtype: float64

# %%
dfhv
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.754270   6.637578  43.068365      1.282422
# 1     0.837019   7.365771  14.485568      0.554229
# 2     0.830539   7.308743  19.011142      0.611257
# 3     0.835473   7.352166  17.876123      0.567834
# 4     0.848650   7.468116   9.758158      0.451884
# ...        ...        ...        ...           ...
# 8756  0.809335   7.122148  25.608082      0.797852
# 8757  0.819186   7.208841  22.647867      0.711159
# 8758  0.823863   7.249993  19.849489      0.670007
# 8759  0.850960   7.488452   9.099814      0.431548
# 8760  0.832502   7.326016  18.755638      0.593984
#
# [8761 rows x 4 columns]

# %%
dfmega2=df.join(dfhv)

# %%
dfmega2
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:47:30.616298              18:13:02.778154
# 1               09:36:51.531057              23:00:00.036000
# 2               08:48:34.676240              17:19:08.527339
# 3               08:23:25.554890              16:13:39.845129
# 4               08:38:32.232027              16:06:30.784198
# ...                         ...                          ...
# 8756            08:57:01.733798              15:55:36.133862
# 8757            08:17:35.527239              15:32:48.027180
# 8758            09:16:10.198706              18:34:05.317121
# 8759            08:37:17.038117              15:23:58.155274
# 8760            11:09:07.815202              16:16:42.263847
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:38:52.080047            17:53:53.427742
# 1               20:10:19.039272            15:38:34.096205
# 2               20:53:50.245552            14:45:00.200717
# 3               19:50:43.053470            16:11:00.263753
# 4               20:12:08.775994            15:10:44.698985
# ...                         ...                        ...
# 8756            20:30:21.342555            16:08:50.808838
# 8757            22:27:20.900498            16:45:56.637893
# 8758            20:31:06.054380            16:15:15.554871
# 8759            20:12:38.371584            14:58:08.904512
# 8760            23:12:42.965486            15:59:13.261934
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                14:19:26.130443               06:21:36.230535
# 1                14:49:15.267049               06:45:16.101426
# 2                13:35:07.160630               07:54:00.702078
# 3                13:51:33.812598               09:24:57.709057
# 4                14:35:19.206656               08:07:59.701619
# ...                          ...                           ...
# 8756             13:18:23.040514               10:48:54.382843
# 8757             13:28:32.331945               06:49:30.565887
# 8758             13:34:15.143999               06:51:06.561406
# 8759             14:28:24.884025               07:00:59.426498
# 8760             14:13:54.720069               08:57:25.479790
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              43.072703  0.754270   6.637578  43.068365      1.282422
# 1              14.498635  0.837019   7.365771  14.485568      0.554229
# 2              19.018282  0.830539   7.308743  19.011142      0.611257
# 3              17.870129  0.835473   7.352166  17.876123      0.567834
# 4               9.802032  0.848650   7.468116   9.758158      0.451884
# ...                  ...       ...        ...        ...           ...
# 8756           25.600789  0.809335   7.122148  25.608082      0.797852
# 8757           22.667008  0.819186   7.208841  22.647867      0.711159
# 8758           19.874952  0.823863   7.249993  19.849489      0.670007
# 8759            9.128183  0.850960   7.488452   9.099814      0.431548
# 8760           18.743991  0.832502   7.326016  18.755638      0.593984
#
# [8761 rows x 11 columns]

# %%
dfmega2.tail
# Out:
# <bound method NDFrame.tail of      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:47:30.616298              18:13:02.778154
# 1               09:36:51.531057              23:00:00.036000
# 2               08:48:34.676240              17:19:08.527339
# 3               08:23:25.554890              16:13:39.845129
# 4               08:38:32.232027              16:06:30.784198
# ...                         ...                          ...
# 8756            08:57:01.733798              15:55:36.133862
# 8757            08:17:35.527239              15:32:48.027180
# 8758            09:16:10.198706              18:34:05.317121
# 8759            08:37:17.038117              15:23:58.155274
# 8760            11:09:07.815202              16:16:42.263847
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:38:52.080047            17:53:53.427742
# 1               20:10:19.039272            15:38:34.096205
# 2               20:53:50.245552            14:45:00.200717
# 3               19:50:43.053470            16:11:00.263753
# 4               20:12:08.775994            15:10:44.698985
# ...                         ...                        ...
# 8756            20:30:21.342555            16:08:50.808838
# 8757            22:27:20.900498            16:45:56.637893
# 8758            20:31:06.054380            16:15:15.554871
# 8759            20:12:38.371584            14:58:08.904512
# 8760            23:12:42.965486            15:59:13.261934
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                14:19:26.130443               06:21:36.230535
# 1                14:49:15.267049               06:45:16.101426
# 2                13:35:07.160630               07:54:00.702078
# 3                13:51:33.812598               09:24:57.709057
# 4                14:35:19.206656               08:07:59.701619
# ...                          ...                           ...
# 8756             13:18:23.040514               10:48:54.382843
# 8757             13:28:32.331945               06:49:30.565887
# 8758             13:34:15.143999               06:51:06.561406
# 8759             14:28:24.884025               07:00:59.426498
# 8760             14:13:54.720069               08:57:25.479790
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              43.072703  0.754270   6.637578  43.068365      1.282422
# 1              14.498635  0.837019   7.365771  14.485568      0.554229
# 2              19.018282  0.830539   7.308743  19.011142      0.611257
# 3              17.870129  0.835473   7.352166  17.876123      0.567834
# 4               9.802032  0.848650   7.468116   9.758158      0.451884
# ...                  ...       ...        ...        ...           ...
# 8756           25.600789  0.809335   7.122148  25.608082      0.797852
# 8757           22.667008  0.819186   7.208841  22.647867      0.711159
# 8758           19.874952  0.823863   7.249993  19.849489      0.670007
# 8759            9.128183  0.850960   7.488452   9.099814      0.431548
# 8760           18.743991  0.832502   7.326016  18.755638      0.593984
#
# [8761 rows x 11 columns]>

# %% [markdown]
# # Merging Power train Simulations with Probability Data For Chevorlet PHEV and BEV

# %%
dfvchev=pd.read_excel('(BEV) Full Discharge 2016 CHEVROLET Spark EV UDDS.xlsx',index_col=0)
dfvchev['distance']=dfvchev['distance']*1.60934
maxEnergy=dfvchev.essCurKwh[0]
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              43.072703  0.794535  16.685231  43.066816      3.894769
# 1              14.498635  0.911705  19.145796  14.506960      1.434204
# 2              19.018282  0.896667  18.829998  19.019757      1.750002
# 3              17.870129  0.900574  18.912056  17.874201      1.667944
# 4               9.802032  0.937204  19.681274   9.800637      0.898726
# ...                  ...       ...        ...        ...           ...
# 8756           25.600789  0.868136  18.230847  25.606624      2.349153
# 8757           22.667008  0.882990  18.542800  22.665597      2.037200
# 8758           19.874952  0.891723  18.726184  19.871693      1.853816
# 8759            9.128183  0.939528  19.730092   9.131856      0.849908
# 8760           18.743991  0.897452  18.846482  18.747908      1.733518
#
# [8761 rows x 11 columns]

# %% [markdown]
# Merging Power train Simulations with Probability Data For Chevorlet PHEV

# %%
dfhvchev=pd.read_excel('(PHEV) Full Discharge 2016 CHEVROLET Volt UDDS.xlsx',index_col=0)

# %%
dfhvchev['distance']=dfhvchev['distance']*1.60934
print("Range")
print(dfhvchev['distance'].iloc[-1])
print(" km")
maxEnergy=dfvchev.essCurKwh[0]
del dfhvchev['mpsAch']
del dfhvchev['essKwOutAch']
del dfhvchev['speed']
dfhvchev['ChgEnergyReq']=maxEnergy-dfhvchev['essCurKwh']
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfhvchev['distance'].sub(x).abs().idxmin())
    
dfhvchev=dfhvchev.loc[tempind]
dfhvchev=dfhvchev.reset_index()
del dfhvchev['index']
# Out:
# Range
# 767.385816747909
#  km

# %%
import matplotlib.pyplot as plt


t = np.linspace(0, 1)
y1 = 2 * np.sin(2*np.pi*t)
y2 = 4 * np.sin(2*np.pi*2*t)

fig, ax = plt.subplots()
ax.set_title('SOC of Chevorlet PHEV and BEV')
line1, = ax.plot(dfhvchev.soc, lw=2, label='PHEV 2016 CHEVROLET Volt')
line2, = ax.plot(dfvchev.soc, lw=2, label='BEV 2016 CHEVROLET Spark')
leg = ax.legend(fancybox=True, shadow=True)

lines = [line1, line2]
lined = {}  # Will map legend lines to original lines.
for legline, origline in zip(leg.get_lines(), lines):
    legline.set_picker(True)  # Enable picking on the legend line.
    lined[legline] = origline


def on_pick(event):
    # On the pick event, find the original line corresponding to the legend
    # proxy line, and toggle its visibility.
    legline = event.artist
    origline = lined[legline]
    visible = not origline.get_visible()
    origline.set_visible(visible)
    # Change the alpha on the line in the legend so we can see what lines
    # have been toggled.
    legline.set_alpha(1.0 if visible else 0.2)
    fig.canvas.draw()

fig.canvas.mpl_connect('pick_event', on_pick)
plt.show()
# Out:
# <div id='41af162f-cec2-474d-bc70-92b9561bb3fa'></div>

# %% [markdown]
# Dataframe for Energy required by EVs

# %%
dfvchev
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.794535  16.685231  43.066816      3.894769
# 1     0.911705  19.145796  14.506960      1.434204
# 2     0.896667  18.829998  19.019757      1.750002
# 3     0.900574  18.912056  17.874201      1.667944
# 4     0.937204  19.681274   9.800637      0.898726
# ...        ...        ...        ...           ...
# 8756  0.868136  18.230847  25.606624      2.349153
# 8757  0.882990  18.542800  22.665597      2.037200
# 8758  0.891723  18.726184  19.871693      1.853816
# 8759  0.939528  19.730092   9.131856      0.849908
# 8760  0.897452  18.846482  18.747908      1.733518
#
# [8761 rows x 4 columns]

# %%
#dfmega3.to_excel('C:/Users/USPCASE/Desktop/Working Folder/NUST-Grid/NUST 65EV.xlsx', sheet_name='EV load')

# %% [markdown]
# # Random Walk to Build 24H Load Profile

# %%
rndindi=np.random.randint(dfmega3.shape[0],size=(10,))
Departure={}
Arrival={}
for i,indi in enumerate(rndindi):
    print(i)
    print(indi)
    # Time Taken to Charge
    Departure[i]=datetime.datetime.combine(datetime.date.today(),(dfmega3.iloc[indi]['Commercial Evening Departure']))
    Arrival[i]=datetime.datetime.combine(datetime.date.today(),(dfmega3.iloc[indi]['Commercial Morning Arrival']))
    if i > 0:
        if Arrival[i] < Departure[i-1]:
            print('Wait For Charging Turn')
        elif Arrival[i] > Departure[i-1]:
            print('Welcome To Charging Station')
Departure
 

# Limit Load Profile to < 24 h means make for a single day >>>>>>>>>>>> Drop values jo raat 12 bje say exceed kare
# Out:
# 0
# 2840
# 1
# 1367
# Wait For Charging Turn
# 2
# 5202
# Wait For Charging Turn
# 3
# 6692
# Wait For Charging Turn
# 4
# 4992
# Wait For Charging Turn
# 5
# 6388
# Wait For Charging Turn
# 6
# 3355
# Wait For Charging Turn
# 7
# 8189
# Wait For Charging Turn
# 8
# 476
# Wait For Charging Turn
# 9
# 4014
# Wait For Charging Turn
# {0: datetime.datetime(2020, 11, 19, 16, 20, 20, 491232),
#  1: datetime.datetime(2020, 11, 19, 19, 20, 53, 922455),
#  2: datetime.datetime(2020, 11, 19, 16, 30, 49, 294134),
#  3: datetime.datetime(2020, 11, 19, 15, 32, 18, 119613),
#  4: datetime.datetime(2020, 11, 19, 17, 13, 13, 21882),
#  5: datetime.datetime(2020, 11, 19, 18, 56, 46, 15724),
#  6: datetime.datetime(2020, 11, 19, 15, 39, 13, 383346),
#  7: datetime.datetime(2020, 11, 19, 16, 55, 37, 488642),
#  8: datetime.datetime(2020, 11, 19, 22, 13, 2, 411205),
#  9: datetime.datetime(2020, 11, 19, 15, 37, 21, 548608)}

# %%
Departure
# Out:
# {0: datetime.datetime(2020, 11, 19, 16, 20, 20, 491232),
#  1: datetime.datetime(2020, 11, 19, 19, 20, 53, 922455),
#  2: datetime.datetime(2020, 11, 19, 16, 30, 49, 294134),
#  3: datetime.datetime(2020, 11, 19, 15, 32, 18, 119613),
#  4: datetime.datetime(2020, 11, 19, 17, 13, 13, 21882),
#  5: datetime.datetime(2020, 11, 19, 18, 56, 46, 15724),
#  6: datetime.datetime(2020, 11, 19, 15, 39, 13, 383346),
#  7: datetime.datetime(2020, 11, 19, 16, 55, 37, 488642),
#  8: datetime.datetime(2020, 11, 19, 22, 13, 2, 411205),
#  9: datetime.datetime(2020, 11, 19, 15, 37, 21, 548608)}

# %% [markdown]
# Different Charging levels  SAE J1772_201210
#
# * level-1  , voltage: 120V AC    ,   Power Level: 1.8KW,
# * level-2  , voltage: 208-240V AC ,  Power Level: 19.2 KW,
# * level-3  , voltage: 480V DC  ,     Power Level: 50KW-150KW

# %%
dfch= dfmega2
dfch=dfch.drop('Commercial Evening Departure',axis=1)
