# %% [markdown]
# # EV Behaviour Rep

# %%
# %matplotlib notebook
import numpy as np
from scipy.stats import genexpon
import matplotlib.pyplot as plt
from numpy.random import RandomState
import pandas as pd

# %%
mu, beta = 8.9068, 0.5492 # location and scale
s = np.random.gumbel(mu, beta, 300)

# %% [markdown]
# # Commercial Feeder EV Arrival and Departure statistics

# %% [markdown]
# #Morning Arrival Commercial Feeders

# %%
from scipy.stats import genextreme

genloc=8.9068    #Shift
genscale=0.5492  #Scale
genc=0.0629  #Shape

x = np.linspace(genextreme.ppf(0.01, genc,loc=genloc,scale=genscale),
                genextreme.ppf(0.99, genc,loc=genloc,scale=genscale), 100)

genvalmarr = genextreme.rvs(genc, loc = genloc, scale=genscale, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x, genextreme.pdf(x, genc,loc=genloc,scale=genscale),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalmarr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='dfdef28c-5b82-46b7-a47d-c98bb9fc9645'></div>
# <div id='8a4dc77e-2a56-464f-ae21-997ad373ee33'></div>

# %%
plt.figure()
plt.plot(genvalmarr)
plt.show()
# Out:
# <div id='fce76e6c-8ec3-4fb6-a2d1-25cbc771489c'></div>

# %% [markdown]
# Evening departure Commercial feeders

# %%
from scipy.stats import genextreme

genloc1= 16.4070    #Shift
genscale1= 1.1106 #Scale
genc1= -0.2821 #Shape

x1 = np.linspace(genextreme.ppf(0.01, genc1 ,loc=genloc1 ,scale=genscale1),
                genextreme.ppf(0.99, genc1 ,loc=genloc1,scale=genscale1), 100)

genvalevdep = genextreme.rvs(genc1, loc = genloc1, scale=genscale1, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x1, genextreme.pdf(x1, genc1,loc=genloc1,scale=genscale1),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalevdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='e5948237-b417-40c4-b853-0e19547d294f'></div>
# <div id='d6d42ac3-6dd1-4233-b7eb-18cbc1ad7f8a'></div>

# %%
plt.figure()
plt.plot(genvalevdep)
plt.show()
# Out:
# <div id='f66edd76-da74-4070-b13c-3c70880c6277'></div>

# %%
import seaborn as sns
sns.boxplot(genvalevdep)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# Limit Data
result=[]
for val in genvalevdep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalevdep
genvalevdep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x1, genextreme.pdf(x1, genc1,loc=genloc1,scale=genscale1),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalevdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='83330288-be18-43c6-b59c-a2101f1b6170'></div>
# <div id='098175d3-467a-4635-8a77-c54be6c3e8c8'></div>

# %%
plt.figure()
plt.plot(genvalevdep)
plt.show()
# Out:
# <div id='8f11b706-eb8c-4c02-b6de-19ed065906b5'></div>

# %% [markdown]
# Night departure Commerical feeders

# %%
from scipy.stats import genextreme

genloc2= 20.5495    #Shift 20.5495
genscale2= 0.5369 #Scale 0.5369
genc2= -0.2779 #Shape -0.2779

x2 = np.linspace(genextreme.ppf(0.01, genc2 ,loc=genloc2 ,scale=genscale2),
                genextreme.ppf(0.99, genc2 ,loc=genloc2,scale=genscale2), 100)

genvalngdep = genextreme.rvs(genc2, loc = genloc2, scale=genscale2, size=8761)

# %%
result=[]
for val in genvalngdep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalngdep
genvalngdep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x2, genextreme.pdf(x2, genc2,loc=genloc2,scale=genscale2),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalngdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='43c638f8-f91a-48e8-a951-00bcac109345'></div>
# <div id='e2758733-3e63-449d-b92e-d7ef0d5eb503'></div>

# %%
plt.figure()
plt.plot(genvalngdep)
plt.show()
# Out:
# <div id='f5f36f42-e68b-4174-980b-9f9ad01b3f04'></div>

# %% [markdown]
# Evening Arrivals Commercial feeders

# %%
from scipy.stats import weibull_min

genscale3= 16.0386 #Scale 16.0386 
genc3=18.0225  #Shape 18.0225
x3 = np.linspace(weibull_min.ppf(0.01, genc3 ,scale=genscale3),
                weibull_min.ppf(0.99, genc3 ,scale=genscale3), 100)

WeibullValEvnArr = weibull_min.rvs(genc3, scale=genscale3, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x3, weibull_min.pdf(x3, genc3,scale=genscale3),
       'r-', lw=5, alpha=0.6, label='Weibull pdf')
ax.hist(WeibullValEvnArr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='308319ec-ba3d-4a3c-b1c1-9662e8e87a4b'></div>
# <div id='62529bce-a2b3-4cd8-807f-b61d13331d62'></div>

# %%
plt.figure()
plt.plot(WeibullValEvnArr)
plt.show()
# Out:
# <div id='687e3e2b-f0a9-44cb-812e-03a230ff8438'></div>

# %% [markdown]
# # Residential feeder EV Arrival and Departure statistics

# %% [markdown]
# Evening Arrival Residentail feeder

# %%
from scipy.stats import genextreme

genloc4= 13.7393    #Shift
genscale4= 0.5129 #Scale
genc4= 0.0631 #Shape

x4 = np.linspace(genextreme.ppf(0.01, genc4 ,loc=genloc4 ,scale=genscale4),
                genextreme.ppf(0.99, genc4 ,loc=genloc4,scale=genscale4), 100)

genvalEvArr = genextreme.rvs(genc4, loc = genloc4, scale=genscale4, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x4, genextreme.pdf(x4, genc4,loc=genloc4,scale=genscale4),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalEvArr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='97a6359d-9887-41f7-9054-c6fb06f4fee3'></div>
# <div id='f45e1546-c044-442b-ab6f-d6b67ef5f9ed'></div>

# %%
plt.figure()
plt.plot(genvalEvArr)
plt.show()
# Out:
# <div id='4a4393e9-36c7-4873-a0cf-9694b32c2f9d'></div>

# %% [markdown]
# Morning Departure Residential feedeer

# %%
from scipy.stats import genextreme

genloc5= 7.0910   #Shift
genscale5= 1.1832 #Scale
genc5= -0.2532 #Shape

x5 = np.linspace(genextreme.ppf(0.01, genc5 ,loc=genloc5 ,scale=genscale5),
                genextreme.ppf(0.99, genc5 ,loc=genloc5,scale=genscale5), 100)

genvalRmordep = genextreme.rvs(genc5, loc = genloc5, scale=genscale5, size=8761)

# %%
result=[]
for val in genvalRmordep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalRmordep
genvalRmordep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x5, genextreme.pdf(x5, genc5,loc=genloc5,scale=genscale5),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalRmordep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='e3e45648-bdeb-4419-8439-0b0cb1d0dfbb'></div>
# <div id='802900fb-a9bf-46ec-bdd7-8f7142c9ea9f'></div>

# %%
plt.figure()
plt.plot(genvalRmordep)
plt.show()
# Out:
# <ipython-input-26-bda56d139d91>:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <div id='d97be555-110a-466a-b545-de5d7c8c89ce'></div>

# %% [markdown]
# # commercial and residential feeder travelled Distance

# %%
from scipy.stats import genextreme

genloc6= 15.8820
genscale6= 7.9015 
genc6= 0.00474

x6 = np.linspace(genextreme.ppf(0.01, genc6 ,loc=genloc6 ,scale=genscale6),
                genextreme.ppf(0.99, genc6 ,loc=genloc6,scale=genscale6), 100)

genvalDistance= genextreme.rvs(genc6, loc = genloc6, scale=genscale6, size=8761)
#genvalDistance=pd.Series((genvalDistance/1.609))
#genvalDistance=genvalDistance.round(decimals=2)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x6, genextreme.pdf(x6, genc6,loc=genloc6,scale=genscale6),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalDistance, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <div id='00dca27c-27df-449c-9315-ad13264ae507'></div>
# <div id='fa06af77-6c80-4be2-88b8-665ba189893d'></div>

# %%
plt.figure()
plt.plot(genvalDistance)
plt.show()
# Out:
# <div id='31902d92-04ba-4af3-b6d3-601035057c52'></div>

# %%
Socinitial= 1-(genvalDistance/30)

# %%
plt.figure()
plt.plot(Socinitial)
plt.show()
# Out:
# <div id='0c511b39-0aba-4a6e-a989-42e479a01bbb'></div>

# %%
import datetime

result=[]

for val in genvalmarr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalmarr
genvalmarr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalevdep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalevdep
genvalevdep=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalngdep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalngdep
genvalngdep=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in WeibullValEvnArr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del WeibullValEvnArr
WeibullValEvnArr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalEvArr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalEvArr
genvalEvArr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalRmordep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalRmordep
genvalRmordep=pd.to_datetime(result, format='%H:%M:%S.%f').time

# %%
df=pd.DataFrame({'Commercial Morning Arrival': genvalmarr,
                 'Commercial Evening Departure': genvalevdep,
                 'Commercial Night Departure': genvalngdep,
                 'Commercial Evening Arrival': WeibullValEvnArr,
                 'Residential Evening Arrival': genvalEvArr,
                 'Residential Morning Arrival': genvalRmordep,
                 'Travelled distance': genvalDistance,
                 'SOCi':Socinitial,  
                })
df
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:55:13.949567              16:41:34.971285
# 1               09:02:48.056191              17:49:07.230166
# 2               09:01:36.118637              18:20:48.439448
# 3               08:33:28.193819              15:41:17.638391
# 4               08:49:32.475692              16:43:45.891100
# ...                         ...                          ...
# 8756            08:38:58.307545              16:12:51.559439
# 8757            10:26:15.056039              16:04:21.595549
# 8758            09:05:15.886060              19:17:45.498512
# 8759            09:22:47.906608              16:00:25.185116
# 8760            08:57:36.354264              17:02:18.149725
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:19:33.588258            15:39:05.598737
# 1               20:54:55.827631            15:16:35.257016
# 2               20:25:23.245569            17:03:29.759035
# 3               20:19:32.014878            15:43:44.191557
# 4               20:03:00.253814            15:09:50.280219
# ...                         ...                        ...
# 8756            20:13:46.949946            16:27:35.346249
# 8757            20:41:03.210136            15:55:05.947900
# 8758            20:29:43.835003            13:14:05.823185
# 8759            19:58:11.048154            16:20:44.180026
# 8760            20:51:57.475096            16:32:27.166781
#
#      Residential Evening Arrival Residential Morning Arrival  \
# 0                13:57:49.622179             10:29:04.994191
# 1                14:56:15.076725             07:46:59.691022
# 2                13:52:08.197390             06:23:31.820790
# 3                14:24:18.803097             10:24:30.433313
# 4                14:15:22.507755             06:53:24.260001
# ...                          ...                         ...
# 8756             13:26:28.343945             08:08:42.646404
# 8757             14:53:23.992429             06:31:44.018610
# 8758             13:19:39.915637             07:17:10.243870
# 8759             13:47:09.817333             08:45:22.053568
# 8760             14:01:55.739487             09:51:27.373861
#
#       Travelled distance      SOCi
# 0              32.243532 -0.074784
# 1              16.027094  0.465764
# 2              12.564355  0.581188
# 3              30.902585 -0.030086
# 4              23.753433  0.208219
# ...                  ...       ...
# 8756           23.967966  0.201068
# 8757           13.320859  0.555971
# 8758           31.434174 -0.047806
# 8759           12.745194  0.575160
# 8760           25.936769  0.135441
#
# [8761 rows x 8 columns]

# %%
#df.to_excel('EVbehaviour.xlsx', engine='xlsxwriter')
df.to_excel('EVbehaviour.xlsx')

# %%
print(df)
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:55:13.949567              16:41:34.971285
# 1               09:02:48.056191              17:49:07.230166
# 2               09:01:36.118637              18:20:48.439448
# 3               08:33:28.193819              15:41:17.638391
# 4               08:49:32.475692              16:43:45.891100
# ...                         ...                          ...
# 8756            08:38:58.307545              16:12:51.559439
# 8757            10:26:15.056039              16:04:21.595549
# 8758            09:05:15.886060              19:17:45.498512
# 8759            09:22:47.906608              16:00:25.185116
# 8760            08:57:36.354264              17:02:18.149725
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:19:33.588258            15:39:05.598737
# 1               20:54:55.827631            15:16:35.257016
# 2               20:25:23.245569            17:03:29.759035
# 3               20:19:32.014878            15:43:44.191557
# 4               20:03:00.253814            15:09:50.280219
# ...                         ...                        ...
# 8756            20:13:46.949946            16:27:35.346249
# 8757            20:41:03.210136            15:55:05.947900
# 8758            20:29:43.835003            13:14:05.823185
# 8759            19:58:11.048154            16:20:44.180026
# 8760            20:51:57.475096            16:32:27.166781
#
#      Residential Evening Arrival Residential Morning Arrival  \
# 0                13:57:49.622179             10:29:04.994191
# 1                14:56:15.076725             07:46:59.691022
# 2                13:52:08.197390             06:23:31.820790
# 3                14:24:18.803097             10:24:30.433313
# 4                14:15:22.507755             06:53:24.260001
# ...                          ...                         ...
# 8756             13:26:28.343945             08:08:42.646404
# 8757             14:53:23.992429             06:31:44.018610
# 8758             13:19:39.915637             07:17:10.243870
# 8759             13:47:09.817333             08:45:22.053568
# 8760             14:01:55.739487             09:51:27.373861
#
#       Travelled distance      SOCi
# 0              32.243532 -0.074784
# 1              16.027094  0.465764
# 2              12.564355  0.581188
# 3              30.902585 -0.030086
# 4              23.753433  0.208219
# ...                  ...       ...
# 8756           23.967966  0.201068
# 8757           13.320859  0.555971
# 8758           31.434174 -0.047806
# 8759           12.745194  0.575160
# 8760           25.936769  0.135441
#
# [8761 rows x 8 columns]

# %% [markdown]
# # Merge PowerTrain Simulations with Probability Data

# %%
dfv=pd.read_excel('(BEV) Full Discharge 2016 Nissan Leaf 30 kWh UDDS.xlsx',index_col=0)
dfv['distance']=dfv['distance']*1.609
maxEnergy=dfv.essCurKwh[0]
del dfv['mpsAch']
del dfv['essKwOutAch']
del dfv['speed']

# %%
dfv['ChgEnergyReq']=maxEnergy-dfv['essCurKwh']
dfv
# Out:
#             soc  essCurKwh    distance  ChgEnergyReq
# 0      0.950000  28.500000    0.000000      0.000000
# 1      0.949998  28.499929    0.000000      0.000071
# 2      0.949995  28.499859    0.000000      0.000141
# 3      0.949993  28.499788    0.000000      0.000212
# 4      0.949991  28.499718    0.000000      0.000282
# ...         ...        ...         ...           ...
# 30539  0.050081   1.502425  268.562905     26.997575
# 30540  0.050078   1.502354  268.562905     26.997646
# 30541  0.050076   1.502284  268.562905     26.997716
# 30542  0.050074   1.502213  268.562905     26.997787
# 30543  0.050058   1.501737  268.564067     26.998263
#
# [30427 rows x 4 columns]

# %% [raw]
# .sub(search_value) subtracts search_value from the df[col_to_search] to make the nearest value almost-zero,
# .abs() makes the almost-zero the minimum of the column,
# .idxmin() yields the df.index of the minimum value, or the closest match to search_value.

# %%
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfv['distance'].sub(x).abs().idxmin())

# %%
dfv=dfv.loc[tempind]
dfv=dfv.reset_index()
del dfv['index']

# %%
df['Travelled distance']
# Out:
# 0       32.243532
# 1       16.027094
# 2       12.564355
# 3       30.902585
# 4       23.753433
#           ...
# 8756    23.967966
# 8757    13.320859
# 8758    31.434174
# 8759    12.745194
# 8760    25.936769
# Name: Travelled distance, Length: 8761, dtype: float64

# %%
dfv
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.839280  25.178394  32.245375      3.321606
# 1     0.891753  26.752585  16.022056      1.747415
# 2     0.907039  27.211157  12.559700      1.288843
# 3     0.843221  25.296617  30.901704      3.203383
# 4     0.869796  26.093875  23.756198      2.406125
# ...        ...        ...        ...           ...
# 8756  0.869372  26.081174  23.968723      2.418826
# 8757  0.905096  27.152877  13.319652      1.347123
# 8758  0.840953  25.228593  31.437241      3.271407
# 8759  0.906196  27.185881  12.747375      1.314119
# 8760  0.858743  25.762297  25.947557      2.737703
#
# [8761 rows x 4 columns]

# %%
dfmega=df.join(dfv)
del dfmega['SOCi']

# %%
dfmega
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:55:13.949567              16:41:34.971285
# 1               09:02:48.056191              17:49:07.230166
# 2               09:01:36.118637              18:20:48.439448
# 3               08:33:28.193819              15:41:17.638391
# 4               08:49:32.475692              16:43:45.891100
# ...                         ...                          ...
# 8756            08:38:58.307545              16:12:51.559439
# 8757            10:26:15.056039              16:04:21.595549
# 8758            09:05:15.886060              19:17:45.498512
# 8759            09:22:47.906608              16:00:25.185116
# 8760            08:57:36.354264              17:02:18.149725
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               21:19:33.588258            15:39:05.598737
# 1               20:54:55.827631            15:16:35.257016
# 2               20:25:23.245569            17:03:29.759035
# 3               20:19:32.014878            15:43:44.191557
# 4               20:03:00.253814            15:09:50.280219
# ...                         ...                        ...
# 8756            20:13:46.949946            16:27:35.346249
# 8757            20:41:03.210136            15:55:05.947900
# 8758            20:29:43.835003            13:14:05.823185
# 8759            19:58:11.048154            16:20:44.180026
# 8760            20:51:57.475096            16:32:27.166781
#
#      Residential Evening Arrival Residential Morning Arrival  \
# 0                13:57:49.622179             10:29:04.994191
# 1                14:56:15.076725             07:46:59.691022
# 2                13:52:08.197390             06:23:31.820790
# 3                14:24:18.803097             10:24:30.433313
# 4                14:15:22.507755             06:53:24.260001
# ...                          ...                         ...
# 8756             13:26:28.343945             08:08:42.646404
# 8757             14:53:23.992429             06:31:44.018610
# 8758             13:19:39.915637             07:17:10.243870
# 8759             13:47:09.817333             08:45:22.053568
# 8760             14:01:55.739487             09:51:27.373861
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              32.243532  0.839280  25.178394  32.245375      3.321606
# 1              16.027094  0.891753  26.752585  16.022056      1.747415
# 2              12.564355  0.907039  27.211157  12.559700      1.288843
# 3              30.902585  0.843221  25.296617  30.901704      3.203383
# 4              23.753433  0.869796  26.093875  23.756198      2.406125
# ...                  ...       ...        ...        ...           ...
# 8756           23.967966  0.869372  26.081174  23.968723      2.418826
# 8757           13.320859  0.905096  27.152877  13.319652      1.347123
# 8758           31.434174  0.840953  25.228593  31.437241      3.271407
# 8759           12.745194  0.906196  27.185881  12.747375      1.314119
# 8760           25.936769  0.858743  25.762297  25.947557      2.737703
#
# [8761 rows x 11 columns]
