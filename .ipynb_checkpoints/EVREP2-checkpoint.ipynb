# %% [markdown]
# # EV Behaviour Rep

# %%
#%matplotlib notebook
import numpy as np
from scipy.stats import genexpon
import matplotlib.pyplot as plt
from numpy.random import RandomState
import pandas as pd

# %% [markdown]
# # Commercial Feeder EV Arrival and Departure statistics

# %% [markdown]
# #Morning Arrival Commercial Feeders

# %%
from scipy.stats import genextreme

genloc=8.9068    #Shift
genscale=0.5492  #Scale
genc=0.0629  #Shape

x = np.linspace(genextreme.ppf(0.01, genc,loc=genloc,scale=genscale),
                genextreme.ppf(0.99, genc,loc=genloc,scale=genscale), 100)

genvalmarr = genextreme.rvs(genc, loc = genloc, scale=genscale, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x, genextreme.pdf(x, genc,loc=genloc,scale=genscale),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalmarr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(genvalmarr)
plt.show()

# %% [markdown]
# Evening departure Commercial feeders

# %%
from scipy.stats import genextreme

genloc1= 16.4070    #Shift
genscale1= 1.1106 #Scale
genc1= -0.2821 #Shape

x1 = np.linspace(genextreme.ppf(0.01, genc1 ,loc=genloc1 ,scale=genscale1),
                genextreme.ppf(0.99, genc1 ,loc=genloc1,scale=genscale1), 100)

genvalevdep = genextreme.rvs(genc1, loc = genloc1, scale=genscale1, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x1, genextreme.pdf(x1, genc1,loc=genloc1,scale=genscale1),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalevdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(genvalevdep)
plt.show()

# %%
import seaborn as sns
sns.boxplot(genvalevdep)

# %%
# Limit Data
result=[]
for val in genvalevdep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalevdep
genvalevdep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x1, genextreme.pdf(x1, genc1,loc=genloc1,scale=genscale1),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalevdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(genvalevdep)
plt.show()

# %% [markdown]
# Night departure Commerical feeders

# %%
from scipy.stats import genextreme

genloc2= 20.5495    #Shift 20.5495
genscale2= 0.5369 #Scale 0.5369
genc2= -0.2779 #Shape -0.2779

x2 = np.linspace(genextreme.ppf(0.01, genc2 ,loc=genloc2 ,scale=genscale2),
                genextreme.ppf(0.99, genc2 ,loc=genloc2,scale=genscale2), 100)

genvalngdep = genextreme.rvs(genc2, loc = genloc2, scale=genscale2, size=8761)

# %%
result=[]
for val in genvalngdep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalngdep
genvalngdep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x2, genextreme.pdf(x2, genc2,loc=genloc2,scale=genscale2),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalngdep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(genvalngdep)
plt.show()

# %% [markdown]
# Evening Arrivals Commercial feeders

# %%
from scipy.stats import weibull_min

genscale3= 16.0386 #Scale 16.0386 
genc3=18.0225  #Shape 18.0225
x3 = np.linspace(weibull_min.ppf(0.01, genc3 ,scale=genscale3),
                weibull_min.ppf(0.99, genc3 ,scale=genscale3), 100)

WeibullValEvnArr = weibull_min.rvs(genc3, scale=genscale3, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x3, weibull_min.pdf(x3, genc3,scale=genscale3),
       'r-', lw=5, alpha=0.6, label='Weibull pdf')
ax.hist(WeibullValEvnArr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(WeibullValEvnArr)
plt.show()

# %% [markdown]
# # Residential feeder EV Arrival and Departure statistics

# %% [markdown]
# Evening Arrival Residentail feeder

# %%
from scipy.stats import genextreme

genloc4= 13.7393    #Shift
genscale4= 0.5129 #Scale
genc4= 0.0631 #Shape

x4 = np.linspace(genextreme.ppf(0.01, genc4 ,loc=genloc4 ,scale=genscale4),
                genextreme.ppf(0.99, genc4 ,loc=genloc4,scale=genscale4), 100)

genvalEvArr = genextreme.rvs(genc4, loc = genloc4, scale=genscale4, size=8761)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x4, genextreme.pdf(x4, genc4,loc=genloc4,scale=genscale4),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalEvArr, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(genvalEvArr)
plt.show()

# %% [markdown]
# Morning Departure Residential feedeer

# %%
from scipy.stats import genextreme

genloc5= 7.0910   #Shift
genscale5= 1.1832 #Scale
genc5= -0.2532 #Shape

x5 = np.linspace(genextreme.ppf(0.01, genc5 ,loc=genloc5 ,scale=genscale5),
                genextreme.ppf(0.99, genc5 ,loc=genloc5,scale=genscale5), 100)

genvalRmordep = genextreme.rvs(genc5, loc = genloc5, scale=genscale5, size=8761)

# %%
result=[]
for val in genvalRmordep:
    if val >=24:
        val=23.00001
        result.append(val)
    else:
        result.append(val)
del genvalRmordep
genvalRmordep=result

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x5, genextreme.pdf(x5, genc5,loc=genloc5,scale=genscale5),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalRmordep, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(genvalRmordep)
plt.show()

# %% [markdown]
# # commercial and residential feeder travelled Distance

# %%
from scipy.stats import genextreme

genloc6= 15.8820
genscale6= 7.9015 
genc6= 0.00474

x6 = np.linspace(genextreme.ppf(0.01, genc6 ,loc=genloc6 ,scale=genscale6),
                genextreme.ppf(0.99, genc6 ,loc=genloc6,scale=genscale6), 100)

genvalDistance= genextreme.rvs(genc6, loc = genloc6, scale=genscale6, size=8761)
#genvalDistance=pd.Series((genvalDistance/1.609))
#genvalDistance=genvalDistance.round(decimals=2)

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
ax.plot(x6, genextreme.pdf(x6, genc6,loc=genloc6,scale=genscale6),
       'r-', lw=5, alpha=0.6, label='genextreme pdf')
ax.hist(genvalDistance, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %%
plt.figure()
plt.plot(genvalDistance)
plt.show()

# %%
import datetime

result=[]

for val in genvalmarr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalmarr
genvalmarr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalevdep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalevdep
genvalevdep=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalngdep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalngdep
genvalngdep=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in WeibullValEvnArr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del WeibullValEvnArr
WeibullValEvnArr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalEvArr:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalEvArr
genvalEvArr=pd.to_datetime(result, format='%H:%M:%S.%f').time

result=[]
for val in genvalRmordep:
    temp = str(datetime.timedelta(hours=val))
    result.append(temp)
del genvalRmordep
genvalRmordep=pd.to_datetime(result, format='%H:%M:%S.%f').time

# %%
df=pd.DataFrame({'Commercial Morning Arrival': genvalmarr,
                 'Commercial Evening Departure': genvalevdep,
                 'Commercial Night Departure': genvalngdep,
                 'Commercial Evening Arrival': WeibullValEvnArr,
                 'Residential Evening Arrival': genvalEvArr,
                 'Residential Morning Departure': genvalRmordep,
                 'Travelled distance': genvalDistance,
                 #'SOCi':Socinitial,  
                })
df
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:44:33.989581              16:16:25.553576
# 1               09:20:46.711759              23:00:00.036000
# 2               09:05:10.705775              16:22:20.828979
# 3               09:08:43.389945              15:26:59.008941
# 4               08:56:23.582545              15:42:38.404648
# ...                         ...                          ...
# 8756            09:00:46.648383              19:57:20.935152
# 8757            10:27:37.706630              19:30:05.533661
# 8758            08:27:34.928088              15:51:18.146638
# 8759            09:53:30.228494              16:56:03.767148
# 8760            08:57:36.450042              18:11:56.163594
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               20:56:00.535569            16:44:02.085124
# 1               20:15:56.353472            15:22:26.301498
# 2               21:08:33.547953            13:52:57.854266
# 3               20:46:21.965490            16:05:01.987915
# 4               20:04:46.904623            15:10:05.046788
# ...                         ...                        ...
# 8756            21:00:00.491653            14:52:26.298873
# 8757            20:00:06.104636            15:22:38.362906
# 8758            21:23:57.912192            15:51:01.560995
# 8759            21:02:04.018166            15:00:12.288965
# 8760            20:48:56.868572            15:20:07.880063
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                13:34:37.888286               16:36:02.652077
# 1                13:19:25.380297               05:42:27.599713
# 2                14:29:24.325018               06:49:01.230827
# 3                13:52:22.811579               07:06:54.982541
# 4                13:49:12.440904               06:16:49.882629
# ...                          ...                           ...
# 8756             14:15:15.378437               08:21:56.726899
# 8757             13:50:04.067982               06:33:08.962723
# 8758             13:34:30.973248               10:28:12.857348
# 8759             13:42:31.136744               06:55:15.601735
# 8760             13:03:30.621798               13:42:14.143109
#
#       Travelled distance
# 0              14.439188
# 1              15.893555
# 2              13.824990
# 3              40.344635
# 4              29.844284
# ...                  ...
# 8756            2.912245
# 8757           28.290413
# 8758           16.817493
# 8759           30.796301
# 8760           25.927843
#
# [8761 rows x 7 columns]

# %%
#df.to_excel('EVbehaviour.xlsx', engine='xlsxwriter')
df.to_excel('EVbehaviour.xlsx')

# %%
print(df)
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:44:33.989581              16:16:25.553576
# 1               09:20:46.711759              23:00:00.036000
# 2               09:05:10.705775              16:22:20.828979
# 3               09:08:43.389945              15:26:59.008941
# 4               08:56:23.582545              15:42:38.404648
# ...                         ...                          ...
# 8756            09:00:46.648383              19:57:20.935152
# 8757            10:27:37.706630              19:30:05.533661
# 8758            08:27:34.928088              15:51:18.146638
# 8759            09:53:30.228494              16:56:03.767148
# 8760            08:57:36.450042              18:11:56.163594
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               20:56:00.535569            16:44:02.085124
# 1               20:15:56.353472            15:22:26.301498
# 2               21:08:33.547953            13:52:57.854266
# 3               20:46:21.965490            16:05:01.987915
# 4               20:04:46.904623            15:10:05.046788
# ...                         ...                        ...
# 8756            21:00:00.491653            14:52:26.298873
# 8757            20:00:06.104636            15:22:38.362906
# 8758            21:23:57.912192            15:51:01.560995
# 8759            21:02:04.018166            15:00:12.288965
# 8760            20:48:56.868572            15:20:07.880063
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                13:34:37.888286               16:36:02.652077
# 1                13:19:25.380297               05:42:27.599713
# 2                14:29:24.325018               06:49:01.230827
# 3                13:52:22.811579               07:06:54.982541
# 4                13:49:12.440904               06:16:49.882629
# ...                          ...                           ...
# 8756             14:15:15.378437               08:21:56.726899
# 8757             13:50:04.067982               06:33:08.962723
# 8758             13:34:30.973248               10:28:12.857348
# 8759             13:42:31.136744               06:55:15.601735
# 8760             13:03:30.621798               13:42:14.143109
#
#       Travelled distance
# 0              14.439188
# 1              15.893555
# 2              13.824990
# 3              40.344635
# 4              29.844284
# ...                  ...
# 8756            2.912245
# 8757           28.290413
# 8758           16.817493
# 8759           30.796301
# 8760           25.927843
#
# [8761 rows x 7 columns]

# %% [markdown]
# # Merge PowerTrain Simulations with Probability Data

# %%
dfv=pd.read_excel('(BEV) Full Discharge 2016 Nissan Leaf 30 kWh UDDS.xlsx',index_col=0)
dfv['distance']=dfv['distance']*1.609
maxEnergy=dfv.essCurKwh[0]
del dfv['mpsAch']
del dfv['essKwOutAch']
del dfv['speed']

# %%
dfv['ChgEnergyReq']=maxEnergy-dfv['essCurKwh']
dfv
# Out:
#             soc  essCurKwh    distance  ChgEnergyReq
# 0      0.950000  28.500000    0.000000      0.000000
# 1      0.949998  28.499929    0.000000      0.000071
# 2      0.949995  28.499859    0.000000      0.000141
# 3      0.949993  28.499788    0.000000      0.000212
# 4      0.949991  28.499718    0.000000      0.000282
# ...         ...        ...         ...           ...
# 30539  0.050081   1.502425  268.562905     26.997575
# 30540  0.050078   1.502354  268.562905     26.997646
# 30541  0.050076   1.502284  268.562905     26.997716
# 30542  0.050074   1.502213  268.562905     26.997787
# 30543  0.050058   1.501737  268.564067     26.998263
#
# [30427 rows x 4 columns]

# %% [raw]
# .sub(search_value) subtracts search_value from the df[col_to_search] to make the nearest value almost-zero,
# .abs() makes the almost-zero the minimum of the column,
# .idxmin() yields the df.index of the minimum value, or the closest match to search_value.

# %%
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfv['distance'].sub(x).abs().idxmin())

# %%
dfv=dfv.loc[tempind]
dfv=dfv.reset_index()
del dfv['index']

# %%
df['Travelled distance']
# Out:
# 0       14.439188
# 1       15.893555
# 2       13.824990
# 3       40.344635
# 4       29.844284
#           ...
# 8756     2.912245
# 8757    28.290413
# 8758    16.817493
# 8759    30.796301
# 8760    25.927843
# Name: Travelled distance, Length: 8761, dtype: float64

# %%
dfv
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.895924  26.877705  14.428137      1.622295
# 1     0.891080  26.732410  15.893021      1.767590
# 2     0.900066  27.001979  13.824842      1.498021
# 3     0.810496  24.314892  40.346598      4.185108
# 4     0.846482  25.394462  29.847658      3.105538
# ...        ...        ...        ...           ...
# 8756  0.934489  28.034675   2.907734      0.465325
# 8757  0.851479  25.544380  28.290523      2.955620
# 8758  0.891112  26.733359  16.817630      1.766641
# 8759  0.843961  25.318826  30.796715      3.181174
# 8760  0.858926  25.767790  25.924539      2.732210
#
# [8761 rows x 4 columns]

# %%
dfmega=df.join(dfv)
#del dfmega['SOCi']

# %%
dfmega
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:44:33.989581              16:16:25.553576
# 1               09:20:46.711759              23:00:00.036000
# 2               09:05:10.705775              16:22:20.828979
# 3               09:08:43.389945              15:26:59.008941
# 4               08:56:23.582545              15:42:38.404648
# ...                         ...                          ...
# 8756            09:00:46.648383              19:57:20.935152
# 8757            10:27:37.706630              19:30:05.533661
# 8758            08:27:34.928088              15:51:18.146638
# 8759            09:53:30.228494              16:56:03.767148
# 8760            08:57:36.450042              18:11:56.163594
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               20:56:00.535569            16:44:02.085124
# 1               20:15:56.353472            15:22:26.301498
# 2               21:08:33.547953            13:52:57.854266
# 3               20:46:21.965490            16:05:01.987915
# 4               20:04:46.904623            15:10:05.046788
# ...                         ...                        ...
# 8756            21:00:00.491653            14:52:26.298873
# 8757            20:00:06.104636            15:22:38.362906
# 8758            21:23:57.912192            15:51:01.560995
# 8759            21:02:04.018166            15:00:12.288965
# 8760            20:48:56.868572            15:20:07.880063
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                13:34:37.888286               16:36:02.652077
# 1                13:19:25.380297               05:42:27.599713
# 2                14:29:24.325018               06:49:01.230827
# 3                13:52:22.811579               07:06:54.982541
# 4                13:49:12.440904               06:16:49.882629
# ...                          ...                           ...
# 8756             14:15:15.378437               08:21:56.726899
# 8757             13:50:04.067982               06:33:08.962723
# 8758             13:34:30.973248               10:28:12.857348
# 8759             13:42:31.136744               06:55:15.601735
# 8760             13:03:30.621798               13:42:14.143109
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              14.439188  0.895924  26.877705  14.428137      1.622295
# 1              15.893555  0.891080  26.732410  15.893021      1.767590
# 2              13.824990  0.900066  27.001979  13.824842      1.498021
# 3              40.344635  0.810496  24.314892  40.346598      4.185108
# 4              29.844284  0.846482  25.394462  29.847658      3.105538
# ...                  ...       ...        ...        ...           ...
# 8756            2.912245  0.934489  28.034675   2.907734      0.465325
# 8757           28.290413  0.851479  25.544380  28.290523      2.955620
# 8758           16.817493  0.891112  26.733359  16.817630      1.766641
# 8759           30.796301  0.843961  25.318826  30.796715      3.181174
# 8760           25.927843  0.858926  25.767790  25.924539      2.732210
#
# [8761 rows x 11 columns]

# %%
dfmega.tail
# Out:
# <bound method NDFrame.tail of      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:44:33.989581              16:16:25.553576
# 1               09:20:46.711759              23:00:00.036000
# 2               09:05:10.705775              16:22:20.828979
# 3               09:08:43.389945              15:26:59.008941
# 4               08:56:23.582545              15:42:38.404648
# ...                         ...                          ...
# 8756            09:00:46.648383              19:57:20.935152
# 8757            10:27:37.706630              19:30:05.533661
# 8758            08:27:34.928088              15:51:18.146638
# 8759            09:53:30.228494              16:56:03.767148
# 8760            08:57:36.450042              18:11:56.163594
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               20:56:00.535569            16:44:02.085124
# 1               20:15:56.353472            15:22:26.301498
# 2               21:08:33.547953            13:52:57.854266
# 3               20:46:21.965490            16:05:01.987915
# 4               20:04:46.904623            15:10:05.046788
# ...                         ...                        ...
# 8756            21:00:00.491653            14:52:26.298873
# 8757            20:00:06.104636            15:22:38.362906
# 8758            21:23:57.912192            15:51:01.560995
# 8759            21:02:04.018166            15:00:12.288965
# 8760            20:48:56.868572            15:20:07.880063
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                13:34:37.888286               16:36:02.652077
# 1                13:19:25.380297               05:42:27.599713
# 2                14:29:24.325018               06:49:01.230827
# 3                13:52:22.811579               07:06:54.982541
# 4                13:49:12.440904               06:16:49.882629
# ...                          ...                           ...
# 8756             14:15:15.378437               08:21:56.726899
# 8757             13:50:04.067982               06:33:08.962723
# 8758             13:34:30.973248               10:28:12.857348
# 8759             13:42:31.136744               06:55:15.601735
# 8760             13:03:30.621798               13:42:14.143109
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              14.439188  0.895924  26.877705  14.428137      1.622295
# 1              15.893555  0.891080  26.732410  15.893021      1.767590
# 2              13.824990  0.900066  27.001979  13.824842      1.498021
# 3              40.344635  0.810496  24.314892  40.346598      4.185108
# 4              29.844284  0.846482  25.394462  29.847658      3.105538
# ...                  ...       ...        ...        ...           ...
# 8756            2.912245  0.934489  28.034675   2.907734      0.465325
# 8757           28.290413  0.851479  25.544380  28.290523      2.955620
# 8758           16.817493  0.891112  26.733359  16.817630      1.766641
# 8759           30.796301  0.843961  25.318826  30.796715      3.181174
# 8760           25.927843  0.858926  25.767790  25.924539      2.732210
#
# [8761 rows x 11 columns]>

# %% [markdown]
# Merging Power train Simulations with probability data for PHEVs prius 2017

# %%
dfhv=pd.read_excel('(PHEV) Full Discharge 2017 Prius Prime UDDS.xlsx',index_col=0)
dfhv['distance']=dfhv['distance']*1.609
maxEnergy=dfhv.essCurKwh[0]
del dfhv['mpsAch']
del dfhv['essKwOutAch']
del dfhv['speed']

# %%
dfhv['ChgEnergyReq']=maxEnergy-dfhv['essCurKwh']
dfhv
# Out:
#             soc  essCurKwh    distance  ChgEnergyReq
# 0      0.900000   7.920000    0.000000      0.000000
# 1      0.899990   7.919915    0.000000      0.000085
# 2      0.899981   7.919831    0.000000      0.000169
# 3      0.899971   7.919746    0.000000      0.000254
# 4      0.899962   7.919662    0.000000      0.000338
# ...         ...        ...         ...           ...
# 87675  0.270340   2.378995  767.222576      5.541005
# 87676  0.270455   2.380006  767.223694      5.539994
# 87677  0.270484   2.380256  767.223694      5.539744
# 87678  0.270502   2.380414  767.223694      5.539586
# 87679  0.270520   2.380572  767.223694      5.539428
#
# [87680 rows x 4 columns]

# %%
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfhv['distance'].sub(x).abs().idxmin())

# %%
dfhv=dfhv.loc[tempind]
dfhv=dfhv.reset_index()
del dfhv['index']

# %%
df['Travelled distance']
# Out:
# 0       14.439188
# 1       15.893555
# 2       13.824990
# 3       40.344635
# 4       29.844284
#           ...
# 8756     2.912245
# 8757    28.290413
# 8758    16.817493
# 8759    30.796301
# 8760    25.927843
# Name: Travelled distance, Length: 8761, dtype: float64

# %%
dfhv
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.702372   6.180875  14.428137      1.739125
# 1     0.688751   6.061013  15.893021      1.858987
# 2     0.715719   6.298329  13.824842      1.621671
# 3     0.391389   3.444221  40.346598      4.475779
# 4     0.524296   4.613803  29.847658      3.306197
# ...        ...        ...        ...           ...
# 8756  0.846127   7.445915   2.907734      0.474085
# 8757  0.542583   4.774727  28.290523      3.145273
# 8758  0.689036   6.063517  16.817630      1.856483
# 8759  0.513546   4.519205  30.796715      3.400795
# 8760  0.564220   4.965136  25.924539      2.954864
#
# [8761 rows x 4 columns]

# %%
dfmega2=df.join(dfhv)

# %%
dfmega2
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:44:33.989581              16:16:25.553576
# 1               09:20:46.711759              23:00:00.036000
# 2               09:05:10.705775              16:22:20.828979
# 3               09:08:43.389945              15:26:59.008941
# 4               08:56:23.582545              15:42:38.404648
# ...                         ...                          ...
# 8756            09:00:46.648383              19:57:20.935152
# 8757            10:27:37.706630              19:30:05.533661
# 8758            08:27:34.928088              15:51:18.146638
# 8759            09:53:30.228494              16:56:03.767148
# 8760            08:57:36.450042              18:11:56.163594
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               20:56:00.535569            16:44:02.085124
# 1               20:15:56.353472            15:22:26.301498
# 2               21:08:33.547953            13:52:57.854266
# 3               20:46:21.965490            16:05:01.987915
# 4               20:04:46.904623            15:10:05.046788
# ...                         ...                        ...
# 8756            21:00:00.491653            14:52:26.298873
# 8757            20:00:06.104636            15:22:38.362906
# 8758            21:23:57.912192            15:51:01.560995
# 8759            21:02:04.018166            15:00:12.288965
# 8760            20:48:56.868572            15:20:07.880063
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                13:34:37.888286               16:36:02.652077
# 1                13:19:25.380297               05:42:27.599713
# 2                14:29:24.325018               06:49:01.230827
# 3                13:52:22.811579               07:06:54.982541
# 4                13:49:12.440904               06:16:49.882629
# ...                          ...                           ...
# 8756             14:15:15.378437               08:21:56.726899
# 8757             13:50:04.067982               06:33:08.962723
# 8758             13:34:30.973248               10:28:12.857348
# 8759             13:42:31.136744               06:55:15.601735
# 8760             13:03:30.621798               13:42:14.143109
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              14.439188  0.702372   6.180875  14.428137      1.739125
# 1              15.893555  0.688751   6.061013  15.893021      1.858987
# 2              13.824990  0.715719   6.298329  13.824842      1.621671
# 3              40.344635  0.391389   3.444221  40.346598      4.475779
# 4              29.844284  0.524296   4.613803  29.847658      3.306197
# ...                  ...       ...        ...        ...           ...
# 8756            2.912245  0.846127   7.445915   2.907734      0.474085
# 8757           28.290413  0.542583   4.774727  28.290523      3.145273
# 8758           16.817493  0.689036   6.063517  16.817630      1.856483
# 8759           30.796301  0.513546   4.519205  30.796715      3.400795
# 8760           25.927843  0.564220   4.965136  25.924539      2.954864
#
# [8761 rows x 11 columns]

# %%
dfmega2.tail
# Out:
# <bound method NDFrame.tail of      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:44:33.989581              16:16:25.553576
# 1               09:20:46.711759              23:00:00.036000
# 2               09:05:10.705775              16:22:20.828979
# 3               09:08:43.389945              15:26:59.008941
# 4               08:56:23.582545              15:42:38.404648
# ...                         ...                          ...
# 8756            09:00:46.648383              19:57:20.935152
# 8757            10:27:37.706630              19:30:05.533661
# 8758            08:27:34.928088              15:51:18.146638
# 8759            09:53:30.228494              16:56:03.767148
# 8760            08:57:36.450042              18:11:56.163594
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               20:56:00.535569            16:44:02.085124
# 1               20:15:56.353472            15:22:26.301498
# 2               21:08:33.547953            13:52:57.854266
# 3               20:46:21.965490            16:05:01.987915
# 4               20:04:46.904623            15:10:05.046788
# ...                         ...                        ...
# 8756            21:00:00.491653            14:52:26.298873
# 8757            20:00:06.104636            15:22:38.362906
# 8758            21:23:57.912192            15:51:01.560995
# 8759            21:02:04.018166            15:00:12.288965
# 8760            20:48:56.868572            15:20:07.880063
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                13:34:37.888286               16:36:02.652077
# 1                13:19:25.380297               05:42:27.599713
# 2                14:29:24.325018               06:49:01.230827
# 3                13:52:22.811579               07:06:54.982541
# 4                13:49:12.440904               06:16:49.882629
# ...                          ...                           ...
# 8756             14:15:15.378437               08:21:56.726899
# 8757             13:50:04.067982               06:33:08.962723
# 8758             13:34:30.973248               10:28:12.857348
# 8759             13:42:31.136744               06:55:15.601735
# 8760             13:03:30.621798               13:42:14.143109
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              14.439188  0.702372   6.180875  14.428137      1.739125
# 1              15.893555  0.688751   6.061013  15.893021      1.858987
# 2              13.824990  0.715719   6.298329  13.824842      1.621671
# 3              40.344635  0.391389   3.444221  40.346598      4.475779
# 4              29.844284  0.524296   4.613803  29.847658      3.306197
# ...                  ...       ...        ...        ...           ...
# 8756            2.912245  0.846127   7.445915   2.907734      0.474085
# 8757           28.290413  0.542583   4.774727  28.290523      3.145273
# 8758           16.817493  0.689036   6.063517  16.817630      1.856483
# 8759           30.796301  0.513546   4.519205  30.796715      3.400795
# 8760           25.927843  0.564220   4.965136  25.924539      2.954864
#
# [8761 rows x 11 columns]>

# %% [markdown]
# # Merging Power train Simulations with Probability Data For Chevorlet PHEV and BEV

# %%
dfvchev=pd.read_excel('(BEV) Full Discharge 2016 CHEVROLET Spark EV UDDS.xlsx',index_col=0)
dfvchev['distance']=dfvchev['distance']*1.60934
maxEnergy=dfvchev.essCurKwh[0]
del dfvchev['mpsAch']
del dfvchev['essKwOutAch']
del dfvchev['speed']

# %%
dfvchev['ChgEnergyReq']=maxEnergy-dfvchev['essCurKwh']
dfvchev
# Out:
#             soc  essCurKwh    distance  ChgEnergyReq
# 0      0.980000  20.580000    0.000000      0.000000
# 1      0.979997  20.579929    0.000000      0.000071
# 2      0.979993  20.579859    0.000000      0.000141
# 3      0.979990  20.579788    0.000000      0.000212
# 4      0.979987  20.579718    0.000000      0.000282
# ...         ...        ...         ...           ...
# 25621  0.030485   0.640195  225.333608     19.939805
# 25622  0.030375   0.637875  225.337452     19.942125
# 25623  0.030217   0.634551  225.342772     19.945449
# 25624  0.030009   0.630194  225.349567     19.949806
# 25683  0.029998   0.629968  225.934170     19.950032
#
# [25604 rows x 4 columns]

# %%
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfvchev['distance'].sub(x).abs().idxmin())

# %%
dfvchev=dfvchev.loc[tempind]
dfvchev=dfvchev.reset_index()
del dfvchev['index']

# %%
dfvchev
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.912164  19.155454  14.431186      1.424546
# 1     0.906151  19.029166  15.896380      1.550834
# 2     0.917363  19.264618  13.827763      1.315382
# 3     0.805198  16.909167  40.340773      3.670833
# 4     0.850319  17.856689  29.843683      2.723311
# ...        ...        ...        ...           ...
# 8756  0.960541  20.171351   2.908348      0.408649
# 8757  0.856664  17.989949  28.284609      2.590051
# 8758  0.906119  19.028500  16.817831      1.551500
# 8759  0.847080  17.788688  30.796696      2.791312
# 8760  0.865774  18.181257  25.930017      2.398743
#
# [8761 rows x 4 columns]

# %%
dfmega3=df.join(dfvchev)

# %%
dfmega3
# Out:
#      Commercial Morning Arrival Commercial Evening Departure  \
# 0               08:44:33.989581              16:16:25.553576
# 1               09:20:46.711759              23:00:00.036000
# 2               09:05:10.705775              16:22:20.828979
# 3               09:08:43.389945              15:26:59.008941
# 4               08:56:23.582545              15:42:38.404648
# ...                         ...                          ...
# 8756            09:00:46.648383              19:57:20.935152
# 8757            10:27:37.706630              19:30:05.533661
# 8758            08:27:34.928088              15:51:18.146638
# 8759            09:53:30.228494              16:56:03.767148
# 8760            08:57:36.450042              18:11:56.163594
#
#      Commercial Night Departure Commercial Evening Arrival  \
# 0               20:56:00.535569            16:44:02.085124
# 1               20:15:56.353472            15:22:26.301498
# 2               21:08:33.547953            13:52:57.854266
# 3               20:46:21.965490            16:05:01.987915
# 4               20:04:46.904623            15:10:05.046788
# ...                         ...                        ...
# 8756            21:00:00.491653            14:52:26.298873
# 8757            20:00:06.104636            15:22:38.362906
# 8758            21:23:57.912192            15:51:01.560995
# 8759            21:02:04.018166            15:00:12.288965
# 8760            20:48:56.868572            15:20:07.880063
#
#      Residential Evening Arrival Residential Morning Departure  \
# 0                13:34:37.888286               16:36:02.652077
# 1                13:19:25.380297               05:42:27.599713
# 2                14:29:24.325018               06:49:01.230827
# 3                13:52:22.811579               07:06:54.982541
# 4                13:49:12.440904               06:16:49.882629
# ...                          ...                           ...
# 8756             14:15:15.378437               08:21:56.726899
# 8757             13:50:04.067982               06:33:08.962723
# 8758             13:34:30.973248               10:28:12.857348
# 8759             13:42:31.136744               06:55:15.601735
# 8760             13:03:30.621798               13:42:14.143109
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              14.439188  0.912164  19.155454  14.431186      1.424546
# 1              15.893555  0.906151  19.029166  15.896380      1.550834
# 2              13.824990  0.917363  19.264618  13.827763      1.315382
# 3              40.344635  0.805198  16.909167  40.340773      3.670833
# 4              29.844284  0.850319  17.856689  29.843683      2.723311
# ...                  ...       ...        ...        ...           ...
# 8756            2.912245  0.960541  20.171351   2.908348      0.408649
# 8757           28.290413  0.856664  17.989949  28.284609      2.590051
# 8758           16.817493  0.906119  19.028500  16.817831      1.551500
# 8759           30.796301  0.847080  17.788688  30.796696      2.791312
# 8760           25.927843  0.865774  18.181257  25.930017      2.398743
#
# [8761 rows x 11 columns]

# %% [markdown]
# Merging Power train Simulations with Probability Data For Chevorlet PHEV

# %%
dfhvchev=pd.read_excel('(PHEV) Full Discharge 2016 CHEVROLET Volt UDDS.xlsx',index_col=0)

# %%
dfhvchev['distance']=dfhvchev['distance']*1.60934
print("Range")
print(dfhvchev['distance'].iloc[-1])
print(" km")
maxEnergy=dfvchev.essCurKwh[0]
del dfhvchev['mpsAch']
del dfhvchev['essKwOutAch']
del dfhvchev['speed']
dfhvchev['ChgEnergyReq']=maxEnergy-dfhvchev['essCurKwh']
tempind=[]

for inter,x in enumerate(df['Travelled distance']):
    tempind.append(dfhvchev['distance'].sub(x).abs().idxmin())
    
dfhvchev=dfhvchev.loc[tempind]
dfhvchev=dfhvchev.reset_index()
del dfhvchev['index']
# Out:
# Range
# 767.385816747909
#  km

# %%
import matplotlib.pyplot as plt


t = np.linspace(0, 1)
y1 = 2 * np.sin(2*np.pi*t)
y2 = 4 * np.sin(2*np.pi*2*t)

fig, ax = plt.subplots()
ax.set_title('SOC of Chevorlet PHEV and BEV')
line1, = ax.plot(dfhvchev.soc, lw=2, label='PHEV 2016 CHEVROLET Volt')
line2, = ax.plot(dfvchev.soc, lw=2, label='BEV 2016 CHEVROLET Spark')
leg = ax.legend(fancybox=True, shadow=True)

lines = [line1, line2]
lined = {}  # Will map legend lines to original lines.
for legline, origline in zip(leg.get_lines(), lines):
    legline.set_picker(True)  # Enable picking on the legend line.
    lined[legline] = origline


def on_pick(event):
    # On the pick event, find the original line corresponding to the legend
    # proxy line, and toggle its visibility.
    legline = event.artist
    origline = lined[legline]
    visible = not origline.get_visible()
    origline.set_visible(visible)
    # Change the alpha on the line in the legend so we can see what lines
    # have been toggled.
    legline.set_alpha(1.0 if visible else 0.2)
    fig.canvas.draw()

fig.canvas.mpl_connect('pick_event', on_pick)
plt.show()

# %% [markdown]
# Dataframe for Energy required by EVs

# %%
dfvchev
# Out:
#            soc  essCurKwh   distance  ChgEnergyReq
# 0     0.912164  19.155454  14.431186      1.424546
# 1     0.906151  19.029166  15.896380      1.550834
# 2     0.917363  19.264618  13.827763      1.315382
# 3     0.805198  16.909167  40.340773      3.670833
# 4     0.850319  17.856689  29.843683      2.723311
# ...        ...        ...        ...           ...
# 8756  0.960541  20.171351   2.908348      0.408649
# 8757  0.856664  17.989949  28.284609      2.590051
# 8758  0.906119  19.028500  16.817831      1.551500
# 8759  0.847080  17.788688  30.796696      2.791312
# 8760  0.865774  18.181257  25.930017      2.398743
#
# [8761 rows x 4 columns]

# %%
#dfmega3.to_excel('C:/Users/USPCASE/Desktop/Working Folder/NUST-Grid/NUST 65EV.xlsx', sheet_name='EV load')

# %% [markdown]
# # Random Walk to Build 24H Load Profile

# %%
rndindi=np.random.randint(dfmega3.shape[0],size=(10,))
Departure={}
Arrival={}
for i,indi in enumerate(rndindi):
    print(i)
    print(indi)
    # Time Taken to Charge
    Departure[i]=datetime.datetime.combine(datetime.date.today(),(dfmega3.iloc[indi]['Commercial Evening Departure']))
    Arrival[i]=datetime.datetime.combine(datetime.date.today(),(dfmega3.iloc[indi]['Commercial Morning Arrival']))
    if i > 0:
        if Arrival[i] < Departure[i-1]:
            print('Wait For Charging Turn')
        elif Arrival[i] > Departure[i-1]:
            print('Welcome To Charging Station')
Departure
 

# Limit Load Profile to < 24 h means make for a single day >>>>>>>>>>>> Drop values jo raat 12 bje say exceed kare
# Out:
# 0
# 311
# 1
# 5524
# Wait For Charging Turn
# 2
# 4230
# Wait For Charging Turn
# 3
# 7246
# Wait For Charging Turn
# 4
# 7003
# Wait For Charging Turn
# 5
# 6001
# Wait For Charging Turn
# 6
# 4880
# Wait For Charging Turn
# 7
# 4994
# Wait For Charging Turn
# 8
# 3452
# Wait For Charging Turn
# 9
# 6973
# Wait For Charging Turn
# {0: datetime.datetime(2020, 11, 25, 15, 37, 14, 420920),
#  1: datetime.datetime(2020, 11, 25, 16, 16, 44, 813790),
#  2: datetime.datetime(2020, 11, 25, 15, 59, 22, 4327),
#  3: datetime.datetime(2020, 11, 25, 16, 25, 28, 500095),
#  4: datetime.datetime(2020, 11, 25, 18, 36, 44, 89794),
#  5: datetime.datetime(2020, 11, 25, 16, 4, 6, 709680),
#  6: datetime.datetime(2020, 11, 25, 16, 56, 56, 169815),
#  7: datetime.datetime(2020, 11, 25, 18, 49, 21, 580909),
#  8: datetime.datetime(2020, 11, 25, 17, 54, 4, 903118),
#  9: datetime.datetime(2020, 11, 25, 17, 35, 20, 841503)}

# %%
Departure
# Out:
# {0: datetime.datetime(2020, 11, 25, 15, 37, 14, 420920),
#  1: datetime.datetime(2020, 11, 25, 16, 16, 44, 813790),
#  2: datetime.datetime(2020, 11, 25, 15, 59, 22, 4327),
#  3: datetime.datetime(2020, 11, 25, 16, 25, 28, 500095),
#  4: datetime.datetime(2020, 11, 25, 18, 36, 44, 89794),
#  5: datetime.datetime(2020, 11, 25, 16, 4, 6, 709680),
#  6: datetime.datetime(2020, 11, 25, 16, 56, 56, 169815),
#  7: datetime.datetime(2020, 11, 25, 18, 49, 21, 580909),
#  8: datetime.datetime(2020, 11, 25, 17, 54, 4, 903118),
#  9: datetime.datetime(2020, 11, 25, 17, 35, 20, 841503)}

# %% [markdown]
# Different Charging levels  SAE J1772_201210
#
# * level-1  , voltage: 120V AC    ,   Power Level: 1.8KW,
# * level-2  , voltage: 208-240V AC ,  Power Level: 19.2 KW,
# * level-3  , voltage: 480V DC  ,     Power Level: 50KW-150KW

# %%
dfch= dfmega2
dfch=dfch.drop('Commercial Evening Departure',axis=1)
dfch=dfch.drop('Commercial Night Departure',axis=1)
dfch=dfch.drop('Residential Morning Departure',axis=1)
dfch
# Out:
#      Commercial Morning Arrival Commercial Evening Arrival  \
# 0               08:44:33.989581            16:44:02.085124
# 1               09:20:46.711759            15:22:26.301498
# 2               09:05:10.705775            13:52:57.854266
# 3               09:08:43.389945            16:05:01.987915
# 4               08:56:23.582545            15:10:05.046788
# ...                         ...                        ...
# 8756            09:00:46.648383            14:52:26.298873
# 8757            10:27:37.706630            15:22:38.362906
# 8758            08:27:34.928088            15:51:01.560995
# 8759            09:53:30.228494            15:00:12.288965
# 8760            08:57:36.450042            15:20:07.880063
#
#      Residential Evening Arrival  Travelled distance       soc  essCurKwh  \
# 0                13:34:37.888286           14.439188  0.702372   6.180875
# 1                13:19:25.380297           15.893555  0.688751   6.061013
# 2                14:29:24.325018           13.824990  0.715719   6.298329
# 3                13:52:22.811579           40.344635  0.391389   3.444221
# 4                13:49:12.440904           29.844284  0.524296   4.613803
# ...                          ...                 ...       ...        ...
# 8756             14:15:15.378437            2.912245  0.846127   7.445915
# 8757             13:50:04.067982           28.290413  0.542583   4.774727
# 8758             13:34:30.973248           16.817493  0.689036   6.063517
# 8759             13:42:31.136744           30.796301  0.513546   4.519205
# 8760             13:03:30.621798           25.927843  0.564220   4.965136
#
#        distance  ChgEnergyReq
# 0     14.428137      1.739125
# 1     15.893021      1.858987
# 2     13.824842      1.621671
# 3     40.346598      4.475779
# 4     29.847658      3.306197
# ...         ...           ...
# 8756   2.907734      0.474085
# 8757  28.290523      3.145273
# 8758  16.817630      1.856483
# 8759  30.796715      3.400795
# 8760  25.924539      2.954864
#
# [8761 rows x 8 columns]

# %% [markdown]
# Calculation of the charging time required to reach 0.95(95%) of SOC
# Tch=(0.95-SOC)* (CAPACITY OF BATTERY)/(RATED POWER OF CHARGER)* EFFICIENCY OF CHARGER

# %%
Tch=[]
Tch=((dfch['ChgEnergyReq'])/(1.8)*(0.95))

Tch2=((dfch['ChgEnergyReq'])/(19.2)*(0.95))

Tch3=((dfch['ChgEnergyReq'])/(50)*(0.95))

dft=pd.DataFrame({'Level1 Charging time':Tch,'Level2 Charging time':Tch2,'Level3 Charging time':Tch3})
dft
# Out:
#       Level1 Charging time  Level2 Charging time  Level3 Charging time
# 0                 0.917871              0.086050              0.033043
# 1                 0.981132              0.091981              0.035321
# 2                 0.855882              0.080239              0.030812
# 3                 2.362216              0.221458              0.085040
# 4                 1.744937              0.163588              0.062818
# ...                    ...                   ...                   ...
# 8756              0.250212              0.023457              0.009008
# 8757              1.660005              0.155625              0.059760
# 8758              0.979810              0.091857              0.035273
# 8759              1.794864              0.168268              0.064615
# 8760              1.559511              0.146204              0.056142
#
# [8761 rows x 3 columns]

# %% [markdown]
# # Departure times Level 1,2 and 3

# %%
#Level1 charging 
depT=[]
for at,ct in zip(dfch['Commercial Morning Arrival'].values,dft['Level1 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(1,'Commercial Morning Departure Level 1',depT)

# %%
depT
# Out:
# [datetime.time(9, 39, 38, 326645),
#  datetime.time(10, 19, 38, 786829),
#  datetime.time(9, 56, 31, 880271),
#  datetime.time(11, 30, 27, 369153),
#  datetime.time(10, 41, 5, 356442),
#  datetime.time(10, 40, 26, 56808),
#  datetime.time(12, 32, 42, 51121),
#  datetime.time(10, 22, 24, 610357),
#  datetime.time(10, 58, 47, 312650),
#  datetime.time(9, 36, 32, 580318),
#  datetime.time(9, 21, 0, 294797),
#  datetime.time(11, 8, 51, 266023),
#  datetime.time(11, 6, 18, 443211),
#  datetime.time(9, 36, 53, 452518),
#  datetime.time(11, 0, 18, 921874),
#  datetime.time(11, 56, 52, 166116),
#  datetime.time(11, 6, 26, 328658),
#  datetime.time(10, 56, 58, 680072),
#  datetime.time(11, 0, 29, 709704),
#  datetime.time(10, 17, 24, 340940),
#  datetime.time(10, 11, 9, 989980),
#  datetime.time(10, 32, 54, 323250),
#  datetime.time(9, 23, 19, 95474),
#  datetime.time(9, 5, 16, 717076),
#  datetime.time(9, 56, 57, 434941),
#  datetime.time(9, 23, 22, 192514),
#  datetime.time(11, 31, 33, 723913),
#  datetime.time(10, 20, 25, 834511),
#  datetime.time(10, 58, 14, 263203),
#  datetime.time(9, 53, 27, 619069),
#  datetime.time(11, 14, 51, 340534),
#  datetime.time(10, 49, 33, 874142),
#  datetime.time(9, 32, 22, 721330),
#  datetime.time(9, 2, 54, 325371),
#  datetime.time(12, 0, 18, 216528),
#  datetime.time(10, 51, 45, 277468),
#  datetime.time(10, 51, 15, 293893),
#  datetime.time(9, 59, 48, 981675),
#  datetime.time(10, 9, 5, 709787),
#  datetime.time(11, 47, 16, 173941),
#  datetime.time(10, 37, 6, 744177),
#  datetime.time(10, 52, 34, 911775),
#  datetime.time(12, 1, 13, 166492),
#  datetime.time(9, 51, 45, 197183),
#  datetime.time(11, 31, 19, 321973),
#  datetime.time(11, 22, 45, 936716),
#  datetime.time(11, 25, 57, 856457),
#  datetime.time(11, 33, 31, 452928),
#  datetime.time(10, 15, 14, 299450),
#  datetime.time(10, 48, 23, 703588),
#  datetime.time(11, 7, 46, 989170),
#  datetime.time(9, 47, 22, 797183),
#  datetime.time(10, 34, 47, 408730),
#  datetime.time(10, 28, 34, 540683),
#  datetime.time(10, 44, 44, 825078),
#  datetime.time(8, 56, 14, 603584),
#  datetime.time(9, 41, 15, 148522),
#  datetime.time(9, 27, 21, 171647),
#  datetime.time(12, 26, 13, 753793),
#  datetime.time(10, 41, 10, 73972),
#  datetime.time(11, 38, 12, 192763),
#  datetime.time(12, 9, 13, 735410),
#  datetime.time(10, 52, 51, 26951),
#  datetime.time(10, 36, 3, 82056),
#  datetime.time(10, 7, 20, 575816),
#  datetime.time(11, 40, 35, 215774),
#  datetime.time(9, 17, 40, 125768),
#  datetime.time(9, 37, 20, 59303),
#  datetime.time(11, 55, 30, 622427),
#  datetime.time(11, 15, 2, 357965),
#  datetime.time(9, 1, 8, 901942),
#  datetime.time(10, 35, 3, 164117),
#  datetime.time(11, 15, 53, 616180),
#  datetime.time(12, 52, 26, 927495),
#  datetime.time(10, 9, 47, 225503),
#  datetime.time(10, 27, 22, 128202),
#  datetime.time(11, 21, 2, 132380),
#  datetime.time(9, 55, 13, 772859),
#  datetime.time(10, 51, 50, 918474),
#  datetime.time(8, 48, 53, 304908),
#  datetime.time(10, 35, 10, 702870),
#  datetime.time(10, 14, 23, 728439),
#  datetime.time(12, 47, 7, 737199),
#  datetime.time(10, 49, 16, 599619),
#  datetime.time(11, 24, 0, 378356),
#  datetime.time(10, 21, 55, 503352),
#  datetime.time(10, 22, 34, 233898),
#  datetime.time(11, 2, 58, 549772),
#  datetime.time(9, 58, 54, 332572),
#  datetime.time(10, 6, 40, 448594),
#  datetime.time(10, 9, 54, 82959),
#  datetime.time(10, 42, 28, 754476),
#  datetime.time(10, 48, 21, 172533),
#  datetime.time(11, 29, 8, 995857),
#  datetime.time(10, 40, 41, 874215),
#  datetime.time(10, 9, 43, 524050),
#  datetime.time(9, 52, 31, 301894),
#  datetime.time(10, 25, 24, 556160),
#  datetime.time(11, 15, 7, 141129),
#  datetime.time(10, 50, 33, 5955),
#  datetime.time(11, 20, 51, 852922),
#  datetime.time(11, 2, 24, 338493),
#  datetime.time(9, 59, 12, 483439),
#  datetime.time(11, 28, 52, 516527),
#  datetime.time(9, 17, 23, 88367),
#  datetime.time(9, 51, 29, 366057),
#  datetime.time(9, 25, 35, 355846),
#  datetime.time(10, 19, 43, 146515),
#  datetime.time(10, 22, 34, 932392),
#  datetime.time(10, 11, 25, 533350),
#  datetime.time(9, 39, 51, 802181),
#  datetime.time(10, 13, 40, 658581),
#  datetime.time(10, 42, 38, 287725),
#  datetime.time(9, 49, 37, 651168),
#  datetime.time(10, 21, 10, 863658),
#  datetime.time(8, 32, 16, 681444),
#  datetime.time(10, 5, 27, 815846),
#  datetime.time(9, 29, 55, 476021),
#  datetime.time(10, 4, 43, 73215),
#  datetime.time(11, 6, 49, 529616),
#  datetime.time(11, 41, 33, 891297),
#  datetime.time(10, 27, 49, 301416),
#  datetime.time(10, 43, 49, 478353),
#  datetime.time(9, 29, 28, 858117),
#  datetime.time(9, 33, 24, 72302),
#  datetime.time(10, 33, 18, 617204),
#  datetime.time(9, 54, 3, 380960),
#  datetime.time(10, 0, 58, 995015),
#  datetime.time(9, 50, 3, 533230),
#  datetime.time(9, 4, 45, 512121),
#  datetime.time(10, 51, 37, 335327),
#  datetime.time(11, 54, 44, 806866),
#  datetime.time(11, 24, 40, 887720),
#  datetime.time(10, 31, 2, 821777),
#  datetime.time(11, 20, 40, 53060),
#  datetime.time(10, 40, 23, 562414),
#  datetime.time(9, 13, 43, 238723),
#  datetime.time(10, 38, 5, 837344),
#  datetime.time(10, 56, 59, 206367),
#  datetime.time(10, 38, 2, 793400),
#  datetime.time(11, 47, 37, 466755),
#  datetime.time(9, 33, 18, 652968),
#  datetime.time(12, 5, 6, 494499),
#  datetime.time(9, 33, 37, 532567),
#  datetime.time(9, 49, 54, 935341),
#  datetime.time(10, 30, 53, 727262),
#  datetime.time(11, 10, 21, 505466),
#  datetime.time(10, 45, 15, 842901),
#  datetime.time(10, 9, 23, 88839),
#  datetime.time(10, 31, 7, 909598),
#  datetime.time(12, 52, 46, 29880),
#  datetime.time(9, 38, 29, 286817),
#  datetime.time(8, 41, 18, 610704),
#  datetime.time(9, 52, 4, 512190),
#  datetime.time(11, 35, 47, 798135),
#  datetime.time(11, 14, 10, 727163),
#  datetime.time(9, 32, 52, 940543),
#  datetime.time(10, 27, 31, 670144),
#  datetime.time(11, 9, 3, 680618),
#  datetime.time(12, 14, 56, 643308),
#  datetime.time(9, 51, 52, 1684),
#  datetime.time(10, 41, 19, 904390),
#  datetime.time(10, 17, 56, 456981),
#  datetime.time(11, 35, 19, 732066),
#  datetime.time(9, 45, 4, 368098),
#  datetime.time(10, 29, 45, 725895),
#  datetime.time(8, 52, 29, 997357),
#  datetime.time(11, 57, 8, 730254),
#  datetime.time(10, 10, 25, 512408),
#  datetime.time(10, 57, 35, 543382),
#  datetime.time(9, 12, 4, 266179),
#  datetime.time(11, 9, 21, 524128),
#  datetime.time(10, 13, 38, 847824),
#  datetime.time(11, 45, 35, 453356),
#  datetime.time(10, 37, 26, 563081),
#  datetime.time(10, 1, 29, 364161),
#  datetime.time(12, 43, 14, 983965),
#  datetime.time(12, 45, 25, 412389),
#  datetime.time(11, 36, 17, 709428),
#  datetime.time(10, 19, 23, 142813),
#  datetime.time(8, 56, 38, 106851),
#  datetime.time(9, 50, 34, 418351),
#  datetime.time(9, 30, 18, 68326),
#  datetime.time(9, 33, 59, 599928),
#  datetime.time(11, 36, 1, 757876),
#  datetime.time(10, 5, 26, 648099),
#  datetime.time(10, 29, 20, 469307),
#  datetime.time(9, 22, 13, 444732),
#  datetime.time(12, 10, 5, 99185),
#  datetime.time(9, 15, 31, 257277),
#  datetime.time(11, 26, 31, 882486),
#  datetime.time(9, 42, 51, 252911),
#  datetime.time(11, 29, 33, 35737),
#  datetime.time(11, 41, 24, 792022),
#  datetime.time(9, 59, 35, 277627),
#  datetime.time(10, 38, 17, 512884),
#  datetime.time(10, 42, 8, 669573),
#  datetime.time(10, 14, 47, 689571),
#  datetime.time(10, 40, 3, 463594),
#  datetime.time(9, 35, 29, 74014),
#  datetime.time(11, 9, 58, 651259),
#  datetime.time(10, 48, 46, 541219),
#  datetime.time(9, 33, 17, 30755),
#  datetime.time(10, 28, 5, 678125),
#  datetime.time(10, 25, 36, 180311),
#  datetime.time(11, 18, 8, 134764),
#  datetime.time(11, 23, 10, 147237),
#  datetime.time(11, 10, 7, 229583),
#  datetime.time(10, 9, 29, 111052),
#  datetime.time(9, 42, 42, 851212),
#  datetime.time(11, 40, 18, 926793),
#  datetime.time(9, 53, 6, 598415),
#  datetime.time(11, 21, 41, 394203),
#  datetime.time(11, 36, 11, 259610),
#  datetime.time(9, 27, 44, 56728),
#  datetime.time(9, 30, 4, 126965),
#  datetime.time(10, 13, 36, 385481),
#  datetime.time(8, 58, 5, 847983),
#  datetime.time(9, 48, 22, 136180),
#  datetime.time(10, 32, 58, 604853),
#  datetime.time(10, 54, 5, 536806),
#  datetime.time(11, 19, 20, 333742),
#  datetime.time(10, 50, 53, 68712),
#  datetime.time(10, 12, 16, 426872),
#  datetime.time(10, 14, 2, 326043),
#  datetime.time(9, 28, 4, 143694),
#  datetime.time(9, 55, 7, 12231),
#  datetime.time(10, 38, 23, 542611),
#  datetime.time(9, 34, 4, 171158),
#  datetime.time(10, 34, 54, 344414),
#  datetime.time(9, 28, 48, 756843),
#  datetime.time(10, 7, 53, 903263),
#  datetime.time(10, 20, 4, 17090),
#  datetime.time(9, 55, 15, 389353),
#  datetime.time(10, 5, 26, 240992),
#  datetime.time(11, 31, 21, 354699),
#  datetime.time(10, 21, 5, 658803),
#  datetime.time(9, 56, 59, 323719),
#  datetime.time(10, 40, 18, 532420),
#  datetime.time(9, 38, 6, 500205),
#  datetime.time(10, 49, 7, 258108),
#  datetime.time(9, 45, 58, 858238),
#  datetime.time(10, 27, 27, 794149),
#  datetime.time(9, 25, 46, 616109),
#  datetime.time(10, 20, 56, 276767),
#  datetime.time(8, 33, 33, 145072),
#  datetime.time(11, 33, 3, 813763),
#  datetime.time(10, 7, 10, 676255),
#  datetime.time(11, 8, 25, 495202),
#  datetime.time(9, 24, 4, 331330),
#  datetime.time(11, 48, 56, 222560),
#  datetime.time(10, 8, 27, 898335),
#  datetime.time(10, 33, 44, 983691),
#  datetime.time(9, 52, 44, 979539),
#  datetime.time(10, 29, 58, 398450),
#  datetime.time(9, 35, 21, 379604),
#  datetime.time(10, 26, 39, 602733),
#  datetime.time(11, 41, 53, 101247),
#  datetime.time(10, 27, 55, 617005),
#  datetime.time(10, 41, 39, 517977),
#  datetime.time(11, 6, 9, 671866),
#  datetime.time(9, 55, 46, 385113),
#  datetime.time(9, 57, 43, 333267),
#  datetime.time(9, 36, 1, 14528),
#  datetime.time(10, 43, 19, 643727),
#  datetime.time(10, 21, 46, 793219),
#  datetime.time(10, 49, 24, 654261),
#  datetime.time(9, 33, 30, 172857),
#  datetime.time(11, 8, 29, 394940),
#  datetime.time(9, 28, 25, 967242),
#  datetime.time(10, 34, 27, 591630),
#  datetime.time(11, 10, 33, 102188),
#  datetime.time(9, 54, 19, 194306),
#  datetime.time(12, 23, 40, 839741),
#  datetime.time(10, 5, 57, 522404),
#  datetime.time(10, 4, 42, 238536),
#  datetime.time(10, 13, 7, 421803),
#  datetime.time(10, 30, 36, 32803),
#  datetime.time(11, 6, 47, 396623),
#  datetime.time(9, 35, 18, 370033),
#  datetime.time(9, 47, 42, 230439),
#  datetime.time(10, 12, 36, 175749),
#  datetime.time(11, 25, 56, 600816),
#  datetime.time(10, 25, 11, 194914),
#  datetime.time(9, 33, 3, 552710),
#  datetime.time(9, 46, 44, 938139),
#  datetime.time(9, 26, 8, 762591),
#  datetime.time(12, 58, 49, 247704),
#  datetime.time(10, 52, 17, 682481),
#  datetime.time(11, 55, 40, 494086),
#  datetime.time(8, 39, 39, 638275),
#  datetime.time(10, 29, 6, 448409),
#  datetime.time(9, 53, 12, 665779),
#  datetime.time(11, 57, 35, 816133),
#  datetime.time(9, 35, 54, 443804),
#  datetime.time(11, 39, 9, 973441),
#  datetime.time(9, 16, 34, 480510),
#  datetime.time(9, 20, 17, 236465),
#  datetime.time(10, 8, 11, 343510),
#  datetime.time(11, 0, 22, 784969),
#  datetime.time(9, 15, 44, 177237),
#  datetime.time(10, 40, 4, 265748),
#  datetime.time(9, 35, 59, 304046),
#  datetime.time(8, 53, 11, 775239),
#  datetime.time(10, 16, 7, 820672),
#  datetime.time(11, 11, 31, 185837),
#  datetime.time(10, 23, 17, 605711),
#  datetime.time(8, 56, 33, 857677),
#  datetime.time(9, 37, 40, 234795),
#  datetime.time(11, 6, 36, 101799),
#  datetime.time(9, 58, 33, 453940),
#  datetime.time(10, 13, 31, 280506),
#  datetime.time(10, 3, 55, 48449),
#  datetime.time(10, 34, 17, 871845),
#  datetime.time(10, 11, 18, 692400),
#  datetime.time(8, 30, 41, 535578),
#  datetime.time(11, 47, 46, 873947),
#  datetime.time(9, 31, 25, 986744),
#  datetime.time(10, 12, 37, 536071),
#  datetime.time(11, 1, 16, 280644),
#  datetime.time(11, 2, 19, 602486),
#  datetime.time(10, 0, 2, 174135),
#  datetime.time(9, 38, 17, 859622),
#  datetime.time(10, 2, 28, 428037),
#  datetime.time(10, 21, 8, 128543),
#  datetime.time(9, 47, 42, 576094),
#  datetime.time(10, 29, 9, 727973),
#  datetime.time(10, 33, 54, 930255),
#  datetime.time(9, 58, 12, 137692),
#  datetime.time(9, 29, 39, 354523),
#  datetime.time(10, 51, 59, 102611),
#  datetime.time(11, 10, 16, 52965),
#  datetime.time(10, 13, 43, 150835),
#  datetime.time(9, 55, 9, 391113),
#  datetime.time(10, 58, 49, 902717),
#  datetime.time(10, 53, 21, 860127),
#  datetime.time(9, 22, 4, 624149),
#  datetime.time(10, 19, 30, 857881),
#  datetime.time(9, 40, 51, 136798),
#  datetime.time(9, 41, 49, 393585),
#  datetime.time(10, 46, 18, 980120),
#  datetime.time(10, 22, 36, 566995),
#  datetime.time(9, 46, 53, 275319),
#  datetime.time(10, 23, 15, 679707),
#  datetime.time(13, 12, 21, 866060),
#  datetime.time(10, 47, 14, 982275),
#  datetime.time(9, 45, 11, 702607),
#  datetime.time(10, 43, 26, 61131),
#  datetime.time(12, 1, 48, 615215),
#  datetime.time(11, 12, 50, 515713),
#  datetime.time(10, 19, 5, 81566),
#  datetime.time(9, 47, 2, 112058),
#  datetime.time(10, 7, 8, 909348),
#  datetime.time(9, 53, 25, 8752),
#  datetime.time(10, 13, 40, 204356),
#  datetime.time(9, 6, 52, 162000),
#  datetime.time(10, 6, 22, 373878),
#  datetime.time(9, 48, 31, 530712),
#  datetime.time(9, 6, 47, 161258),
#  datetime.time(10, 4, 44, 602382),
#  datetime.time(10, 37, 33, 34681),
#  datetime.time(10, 43, 29, 498534),
#  datetime.time(10, 57, 55, 811776),
#  datetime.time(9, 17, 0, 835248),
#  datetime.time(12, 25, 53, 233133),
#  datetime.time(9, 32, 3, 792015),
#  datetime.time(10, 39, 21, 704508),
#  datetime.time(9, 14, 25, 702540),
#  datetime.time(10, 49, 5, 900408),
#  datetime.time(9, 57, 52, 367450),
#  datetime.time(10, 25, 36, 87143),
#  datetime.time(10, 12, 41, 277866),
#  datetime.time(12, 10, 42, 516849),
#  datetime.time(9, 28, 17, 657322),
#  datetime.time(9, 59, 31, 274520),
#  datetime.time(10, 4, 24, 624151),
#  datetime.time(9, 50, 59, 862444),
#  datetime.time(9, 57, 21, 755905),
#  datetime.time(10, 55, 8, 888113),
#  datetime.time(10, 4, 13, 833098),
#  datetime.time(10, 29, 30, 83118),
#  datetime.time(13, 9, 33, 361904),
#  datetime.time(10, 45, 57, 148893),
#  datetime.time(9, 50, 11, 691099),
#  datetime.time(10, 37, 57, 232976),
#  datetime.time(9, 7, 12, 274308),
#  datetime.time(9, 50, 21, 109319),
#  datetime.time(10, 15, 38, 668303),
#  datetime.time(10, 3, 17, 191351),
#  datetime.time(10, 11, 24, 104130),
#  datetime.time(10, 37, 38, 23148),
#  datetime.time(9, 49, 34, 109924),
#  datetime.time(9, 7, 34, 274975),
#  datetime.time(11, 1, 45, 360612),
#  datetime.time(10, 2, 49, 381065),
#  datetime.time(10, 8, 7, 558695),
#  datetime.time(10, 31, 42, 307124),
#  datetime.time(9, 10, 29, 806724),
#  datetime.time(9, 4, 13, 150243),
#  datetime.time(9, 32, 17, 491446),
#  datetime.time(9, 13, 4, 392319),
#  datetime.time(11, 10, 54, 397043),
#  datetime.time(10, 25, 8, 141703),
#  datetime.time(9, 57, 47, 171481),
#  datetime.time(10, 3, 47, 992113),
#  datetime.time(12, 15, 40, 895424),
#  datetime.time(10, 10, 21, 205488),
#  datetime.time(10, 43, 42, 807017),
#  datetime.time(9, 25, 52, 872017),
#  datetime.time(10, 53, 9, 310127),
#  datetime.time(10, 40, 47, 559544),
#  datetime.time(10, 33, 36, 286387),
#  datetime.time(11, 56, 3, 911261),
#  datetime.time(9, 34, 51, 640789),
#  datetime.time(10, 25, 7, 81917),
#  datetime.time(9, 55, 27, 357374),
#  datetime.time(9, 51, 32, 779284),
#  datetime.time(10, 45, 0, 284906),
#  datetime.time(12, 24, 0, 547215),
#  datetime.time(10, 53, 12, 516043),
#  datetime.time(10, 36, 22, 85849),
#  datetime.time(10, 37, 24, 826076),
#  datetime.time(10, 26, 44, 551891),
#  datetime.time(11, 42, 36, 288639),
#  datetime.time(10, 56, 17, 743729),
#  datetime.time(10, 9, 10, 709305),
#  datetime.time(10, 27, 7, 861251),
#  datetime.time(10, 30, 56, 952278),
#  datetime.time(10, 45, 38, 652716),
#  datetime.time(12, 5, 32, 779427),
#  datetime.time(10, 28, 8, 298782),
#  datetime.time(10, 52, 22, 118214),
#  datetime.time(10, 23, 39, 908243),
#  datetime.time(10, 44, 2, 933166),
#  datetime.time(9, 46, 32, 479514),
#  datetime.time(9, 8, 14, 210772),
#  datetime.time(9, 2, 5, 106823),
#  datetime.time(12, 21, 0, 787557),
#  datetime.time(9, 25, 25, 119458),
#  datetime.time(8, 59, 47, 426134),
#  datetime.time(11, 9, 8, 109267),
#  datetime.time(10, 5, 3, 340178),
#  datetime.time(9, 38, 12, 54554),
#  datetime.time(9, 34, 24, 928681),
#  datetime.time(10, 3, 2, 696874),
#  datetime.time(10, 48, 26, 267449),
#  datetime.time(9, 26, 32, 175757),
#  datetime.time(10, 50, 11, 744256),
#  datetime.time(10, 26, 14, 339992),
#  datetime.time(10, 53, 44, 719743),
#  datetime.time(7, 53, 55, 120236),
#  datetime.time(10, 31, 47, 380198),
#  datetime.time(10, 40, 14, 767133),
#  datetime.time(11, 48, 37, 500632),
#  datetime.time(10, 41, 6, 41513),
#  datetime.time(10, 6, 18, 711044),
#  datetime.time(10, 15, 46, 104105),
#  datetime.time(10, 16, 0, 140903),
#  datetime.time(9, 54, 6, 934541),
#  datetime.time(10, 1, 44, 768723),
#  datetime.time(10, 4, 28, 142371),
#  datetime.time(11, 21, 1, 223586),
#  datetime.time(10, 34, 17, 901099),
#  datetime.time(10, 45, 22, 705525),
#  datetime.time(10, 9, 37, 333241),
#  datetime.time(10, 25, 33, 789738),
#  datetime.time(9, 47, 24, 122124),
#  datetime.time(9, 52, 2, 98101),
#  datetime.time(10, 10, 58, 641935),
#  datetime.time(9, 43, 7, 92092),
#  datetime.time(9, 59, 38, 821540),
#  datetime.time(10, 25, 41, 502812),
#  datetime.time(10, 0, 58, 799018),
#  datetime.time(9, 41, 27, 53379),
#  datetime.time(10, 17, 23, 305206),
#  datetime.time(9, 46, 8, 400608),
#  datetime.time(11, 30, 36, 663878),
#  datetime.time(11, 33, 3, 166751),
#  datetime.time(10, 16, 58, 675883),
#  datetime.time(10, 52, 1, 117720),
#  datetime.time(12, 26, 25, 511724),
#  datetime.time(10, 1, 15, 752559),
#  datetime.time(9, 24, 1, 928697),
#  datetime.time(11, 13, 35, 988898),
#  datetime.time(10, 2, 21, 372845),
#  datetime.time(10, 36, 13, 17587),
#  datetime.time(11, 34, 23, 335418),
#  datetime.time(10, 18, 42, 309468),
#  datetime.time(12, 18, 9, 30065),
#  datetime.time(9, 47, 52, 621986),
#  datetime.time(10, 4, 42, 587362),
#  datetime.time(10, 39, 10, 313679),
#  datetime.time(9, 42, 54, 211788),
#  datetime.time(9, 36, 58, 641567),
#  datetime.time(11, 22, 2, 833965),
#  datetime.time(11, 33, 3, 914670),
#  datetime.time(9, 41, 50, 926674),
#  datetime.time(9, 50, 30, 779374),
#  datetime.time(11, 57, 59, 607647),
#  datetime.time(10, 51, 13, 387242),
#  datetime.time(11, 17, 45, 552680),
#  datetime.time(11, 57, 7, 850828),
#  datetime.time(12, 25, 28, 645581),
#  datetime.time(11, 46, 25, 934634),
#  datetime.time(10, 48, 3, 610592),
#  datetime.time(10, 7, 17, 646331),
#  datetime.time(10, 31, 29, 17312),
#  datetime.time(9, 25, 19, 5590),
#  datetime.time(11, 24, 34, 315695),
#  datetime.time(10, 10, 11, 262214),
#  datetime.time(10, 59, 6, 652104),
#  datetime.time(9, 58, 23, 384330),
#  datetime.time(11, 54, 30, 786255),
#  datetime.time(10, 5, 25, 830196),
#  datetime.time(9, 3, 56, 860951),
#  datetime.time(10, 1, 50, 772113),
#  datetime.time(11, 18, 46, 946492),
#  datetime.time(11, 42, 19, 609390),
#  datetime.time(9, 55, 33, 547064),
#  datetime.time(9, 49, 18, 725106),
#  datetime.time(9, 32, 47, 126440),
#  datetime.time(10, 14, 36, 662873),
#  datetime.time(10, 13, 29, 34448),
#  datetime.time(10, 35, 26, 377631),
#  datetime.time(10, 20, 32, 913185),
#  datetime.time(10, 53, 25, 922924),
#  datetime.time(11, 6, 42, 152353),
#  datetime.time(9, 33, 9, 729409),
#  datetime.time(11, 6, 32, 509052),
#  datetime.time(10, 37, 19, 210692),
#  datetime.time(10, 15, 31, 45530),
#  datetime.time(9, 31, 27, 460899),
#  datetime.time(10, 33, 36, 787656),
#  datetime.time(9, 57, 13, 905905),
#  datetime.time(9, 59, 13, 362892),
#  datetime.time(12, 1, 55, 452341),
#  datetime.time(10, 7, 49, 907047),
#  datetime.time(9, 29, 45, 745838),
#  datetime.time(10, 9, 2, 938455),
#  datetime.time(9, 9, 34, 846899),
#  datetime.time(11, 2, 35, 174423),
#  datetime.time(10, 24, 11, 372205),
#  datetime.time(10, 14, 32, 72820),
#  datetime.time(9, 40, 36, 954596),
#  datetime.time(10, 49, 7, 176690),
#  datetime.time(10, 31, 39, 88999),
#  datetime.time(10, 12, 35, 751669),
#  datetime.time(9, 42, 33, 199091),
#  datetime.time(8, 42, 30, 394814),
#  datetime.time(9, 40, 54, 184664),
#  datetime.time(10, 15, 30, 37820),
#  datetime.time(9, 13, 10, 672147),
#  datetime.time(11, 13, 25, 960514),
#  datetime.time(10, 28, 2, 58657),
#  datetime.time(8, 59, 53, 925377),
#  datetime.time(9, 25, 47, 463383),
#  datetime.time(9, 37, 13, 641159),
#  datetime.time(9, 40, 33, 325982),
#  datetime.time(11, 3, 28, 671029),
#  datetime.time(11, 16, 48, 278709),
#  datetime.time(11, 2, 44, 555974),
#  datetime.time(9, 44, 39, 988524),
#  datetime.time(11, 44, 50, 841526),
#  datetime.time(10, 50, 31, 977649),
#  datetime.time(12, 13, 57, 834108),
#  datetime.time(10, 44, 36, 556987),
#  datetime.time(10, 16, 26, 22308),
#  datetime.time(9, 58, 39, 688713),
#  datetime.time(11, 12, 29, 308705),
#  datetime.time(11, 36, 52, 747915),
#  datetime.time(10, 4, 35, 95913),
#  datetime.time(11, 34, 17, 519835),
#  datetime.time(10, 44, 54, 607889),
#  datetime.time(10, 20, 53, 785149),
#  datetime.time(9, 9, 26, 204726),
#  datetime.time(9, 49, 15, 104419),
#  datetime.time(9, 26, 14, 655880),
#  datetime.time(10, 12, 41, 316617),
#  datetime.time(10, 35, 12, 709280),
#  datetime.time(10, 9, 7, 351605),
#  datetime.time(9, 47, 36, 848107),
#  datetime.time(10, 47, 8, 554237),
#  datetime.time(11, 37, 53, 166884),
#  datetime.time(10, 34, 55, 911092),
#  datetime.time(9, 35, 27, 823480),
#  datetime.time(11, 58, 6, 335348),
#  datetime.time(10, 41, 25, 858211),
#  datetime.time(8, 57, 49, 518298),
#  datetime.time(9, 58, 38, 434074),
#  datetime.time(13, 9, 41, 303022),
#  datetime.time(9, 54, 22, 305518),
#  datetime.time(8, 57, 31, 52812),
#  datetime.time(10, 16, 45, 373609),
#  datetime.time(12, 29, 26, 267456),
#  datetime.time(10, 35, 27, 396585),
#  datetime.time(10, 11, 56, 409376),
#  datetime.time(9, 29, 24, 500640),
#  datetime.time(11, 51, 20, 272530),
#  datetime.time(10, 36, 12, 642209),
#  datetime.time(10, 31, 17, 437246),
#  datetime.time(9, 52, 15, 755439),
#  datetime.time(10, 26, 11, 726157),
#  datetime.time(10, 13, 44, 680167),
#  datetime.time(9, 52, 31, 791777),
#  datetime.time(12, 23, 7, 313016),
#  datetime.time(11, 1, 36, 4280),
#  datetime.time(10, 26, 29, 90990),
#  datetime.time(10, 41, 52, 895033),
#  datetime.time(11, 50, 2, 705522),
#  datetime.time(10, 1, 3, 463715),
#  datetime.time(10, 47, 59, 121979),
#  datetime.time(10, 26, 14, 479665),
#  datetime.time(11, 9, 41, 380212),
#  datetime.time(9, 46, 52, 761172),
#  datetime.time(9, 29, 12, 787242),
#  datetime.time(9, 51, 8, 219242),
#  datetime.time(10, 10, 26, 546661),
#  datetime.time(11, 44, 0, 342618),
#  datetime.time(10, 49, 51, 581664),
#  datetime.time(10, 5, 28, 105934),
#  datetime.time(9, 59, 16, 789538),
#  datetime.time(9, 42, 12, 944992),
#  datetime.time(11, 45, 36, 954374),
#  datetime.time(10, 48, 39, 418077),
#  datetime.time(11, 21, 44, 521839),
#  datetime.time(11, 27, 5, 920581),
#  datetime.time(12, 1, 44, 601665),
#  datetime.time(10, 16, 38, 769396),
#  datetime.time(11, 11, 37, 256268),
#  datetime.time(10, 49, 46, 829088),
#  datetime.time(10, 50, 23, 630013),
#  datetime.time(10, 20, 0, 228531),
#  datetime.time(10, 43, 17, 276641),
#  datetime.time(11, 41, 50, 776657),
#  datetime.time(9, 37, 3, 472689),
#  datetime.time(9, 26, 5, 986024),
#  datetime.time(11, 37, 10, 817570),
#  datetime.time(9, 42, 20, 732983),
#  datetime.time(9, 37, 40, 128772),
#  datetime.time(9, 32, 28, 473928),
#  datetime.time(9, 18, 38, 239890),
#  datetime.time(9, 29, 44, 840742),
#  datetime.time(11, 27, 18, 201573),
#  datetime.time(10, 46, 27, 419847),
#  datetime.time(9, 56, 9, 599911),
#  datetime.time(10, 40, 11, 469673),
#  datetime.time(9, 37, 7, 598103),
#  datetime.time(10, 33, 42, 337832),
#  datetime.time(9, 51, 10, 733885),
#  datetime.time(9, 31, 18, 148624),
#  datetime.time(9, 53, 34, 221435),
#  datetime.time(10, 47, 18, 713004),
#  datetime.time(9, 13, 57, 716338),
#  datetime.time(11, 31, 47, 976341),
#  datetime.time(9, 31, 17, 568413),
#  datetime.time(11, 29, 49, 289659),
#  datetime.time(9, 45, 17, 88959),
#  datetime.time(11, 15, 51, 666754),
#  datetime.time(10, 25, 25, 793263),
#  datetime.time(10, 20, 12, 132392),
#  datetime.time(11, 38, 52, 31006),
#  datetime.time(10, 49, 26, 807790),
#  datetime.time(10, 59, 9, 268639),
#  datetime.time(10, 25, 17, 745018),
#  datetime.time(11, 12, 6, 744216),
#  datetime.time(10, 37, 43, 921860),
#  datetime.time(11, 15, 32, 99264),
#  datetime.time(10, 37, 28, 677344),
#  datetime.time(12, 40, 28, 586562),
#  datetime.time(10, 21, 8, 838458),
#  datetime.time(11, 45, 16, 908698),
#  datetime.time(9, 31, 51, 230987),
#  datetime.time(10, 16, 16, 490253),
#  datetime.time(10, 57, 39, 985566),
#  datetime.time(11, 16, 46, 440724),
#  datetime.time(11, 26, 4, 149720),
#  datetime.time(10, 45, 36, 92873),
#  datetime.time(9, 30, 15, 764816),
#  datetime.time(11, 57, 31, 619068),
#  datetime.time(10, 34, 27, 539656),
#  datetime.time(11, 19, 23, 440054),
#  datetime.time(13, 5, 2, 957554),
#  datetime.time(10, 37, 10, 344791),
#  datetime.time(10, 57, 32, 593925),
#  datetime.time(10, 43, 30, 917738),
#  datetime.time(10, 59, 12, 230207),
#  datetime.time(10, 33, 21, 360401),
#  datetime.time(9, 46, 3, 353697),
#  datetime.time(10, 11, 59, 418345),
#  datetime.time(9, 18, 45, 283322),
#  datetime.time(10, 7, 43, 22645),
#  datetime.time(9, 55, 8, 558044),
#  datetime.time(12, 6, 4, 899476),
#  datetime.time(11, 14, 14, 161761),
#  datetime.time(11, 13, 42, 759560),
#  datetime.time(8, 46, 50, 523262),
#  datetime.time(10, 2, 9, 155045),
#  datetime.time(11, 4, 46, 616586),
#  datetime.time(11, 46, 46, 733394),
#  datetime.time(9, 53, 7, 591367),
#  datetime.time(9, 53, 14, 393552),
#  datetime.time(10, 2, 52, 897109),
#  datetime.time(10, 10, 43, 962028),
#  datetime.time(9, 29, 26, 473567),
#  datetime.time(10, 46, 26, 238465),
#  datetime.time(10, 12, 19, 700663),
#  datetime.time(10, 43, 47, 93867),
#  datetime.time(10, 2, 25, 381529),
#  datetime.time(9, 2, 51, 70161),
#  datetime.time(9, 25, 5, 752494),
#  datetime.time(11, 30, 29, 180950),
#  datetime.time(12, 21, 34, 34885),
#  datetime.time(9, 48, 54, 71713),
#  datetime.time(10, 8, 55, 586320),
#  datetime.time(9, 29, 24, 766138),
#  datetime.time(11, 9, 54, 859057),
#  datetime.time(10, 25, 44, 847723),
#  datetime.time(10, 28, 50, 531647),
#  datetime.time(9, 48, 20, 412150),
#  datetime.time(10, 30, 58, 288998),
#  datetime.time(9, 53, 34, 24967),
#  datetime.time(10, 48, 18, 212835),
#  datetime.time(9, 44, 49, 933541),
#  datetime.time(9, 55, 51, 754028),
#  datetime.time(9, 42, 54, 301417),
#  datetime.time(12, 19, 7, 56110),
#  datetime.time(10, 51, 3, 20154),
#  datetime.time(10, 51, 16, 435970),
#  datetime.time(10, 23, 38, 335204),
#  datetime.time(10, 27, 7, 698408),
#  datetime.time(9, 48, 51, 323447),
#  datetime.time(10, 54, 1, 70416),
#  datetime.time(10, 50, 37, 220300),
#  datetime.time(10, 8, 4, 999296),
#  datetime.time(8, 55, 0, 553791),
#  datetime.time(10, 5, 17, 2505),
#  datetime.time(11, 19, 3, 320099),
#  datetime.time(10, 37, 7, 533005),
#  datetime.time(9, 45, 58, 330401),
#  datetime.time(10, 33, 38, 718406),
#  datetime.time(12, 17, 1, 757848),
#  datetime.time(10, 18, 16, 436454),
#  datetime.time(9, 27, 46, 209164),
#  datetime.time(10, 58, 33, 552555),
#  datetime.time(10, 16, 3, 652661),
#  datetime.time(11, 12, 44, 982172),
#  datetime.time(10, 51, 2, 399865),
#  datetime.time(9, 51, 57, 927558),
#  datetime.time(10, 12, 13, 979614),
#  datetime.time(9, 59, 55, 49385),
#  datetime.time(10, 43, 27, 92907),
#  datetime.time(9, 37, 56, 788995),
#  datetime.time(10, 50, 27, 25349),
#  datetime.time(10, 47, 38, 46806),
#  datetime.time(9, 47, 20, 418595),
#  datetime.time(9, 56, 52, 115259),
#  datetime.time(9, 33, 5, 144128),
#  datetime.time(10, 1, 49, 159219),
#  datetime.time(11, 57, 21, 482306),
#  datetime.time(12, 0, 53, 68744),
#  datetime.time(10, 31, 24, 440290),
#  datetime.time(9, 41, 4, 995102),
#  datetime.time(9, 11, 7, 618677),
#  datetime.time(8, 52, 1, 718373),
#  datetime.time(9, 13, 44, 214606),
#  datetime.time(10, 21, 57, 828080),
#  datetime.time(9, 38, 9, 393028),
#  datetime.time(9, 45, 14, 126412),
#  datetime.time(10, 11, 37, 848157),
#  datetime.time(10, 0, 55, 652062),
#  datetime.time(10, 42, 46, 367912),
#  datetime.time(9, 2, 32, 735932),
#  datetime.time(10, 12, 40, 955026),
#  datetime.time(9, 47, 47, 555364),
#  datetime.time(9, 23, 5, 549470),
#  datetime.time(11, 20, 21, 623369),
#  datetime.time(9, 16, 56, 380733),
#  datetime.time(9, 10, 10, 439202),
#  datetime.time(10, 17, 26, 665256),
#  datetime.time(10, 0, 12, 610374),
#  datetime.time(10, 3, 54, 773753),
#  datetime.time(10, 40, 3, 732143),
#  datetime.time(10, 46, 14, 79813),
#  datetime.time(10, 36, 48, 612882),
#  datetime.time(10, 28, 45, 350211),
#  datetime.time(9, 49, 57, 529962),
#  datetime.time(11, 21, 17, 852661),
#  datetime.time(9, 24, 18, 999331),
#  datetime.time(10, 40, 23, 897481),
#  datetime.time(9, 37, 14, 802391),
#  datetime.time(9, 41, 17, 4246),
#  datetime.time(11, 57, 53, 488260),
#  datetime.time(10, 21, 3, 446685),
#  datetime.time(10, 51, 47, 64662),
#  datetime.time(9, 40, 6, 962261),
#  datetime.time(12, 59, 32, 271052),
#  datetime.time(11, 22, 13, 217237),
#  datetime.time(9, 46, 18, 771680),
#  datetime.time(10, 59, 39, 441161),
#  datetime.time(10, 45, 39, 444420),
#  datetime.time(10, 55, 45, 957734),
#  datetime.time(11, 35, 36, 15383),
#  datetime.time(9, 40, 0, 175621),
#  datetime.time(9, 5, 40, 313212),
#  datetime.time(9, 55, 51, 599529),
#  datetime.time(12, 46, 50, 787606),
#  datetime.time(10, 1, 51, 385081),
#  datetime.time(10, 8, 23, 894386),
#  datetime.time(11, 29, 6, 211832),
#  datetime.time(11, 12, 25, 346858),
#  datetime.time(11, 4, 28, 2858),
#  datetime.time(11, 24, 40, 14234),
#  datetime.time(10, 7, 40, 696792),
#  datetime.time(11, 24, 19, 242557),
#  datetime.time(9, 41, 52, 341318),
#  datetime.time(10, 7, 25, 627956),
#  datetime.time(11, 1, 37, 177007),
#  datetime.time(10, 23, 4, 510391),
#  datetime.time(11, 3, 24, 423679),
#  datetime.time(11, 14, 57, 851312),
#  datetime.time(11, 21, 9, 172524),
#  datetime.time(9, 17, 40, 452996),
#  datetime.time(11, 26, 53, 265839),
#  datetime.time(10, 31, 23, 120913),
#  datetime.time(11, 43, 59, 39846),
#  datetime.time(9, 44, 55, 743855),
#  datetime.time(10, 7, 36, 480919),
#  datetime.time(10, 51, 53, 771616),
#  datetime.time(10, 42, 22, 372985),
#  datetime.time(10, 44, 50, 344100),
#  datetime.time(10, 52, 33, 266774),
#  datetime.time(10, 17, 26, 479253),
#  datetime.time(10, 22, 25, 890180),
#  datetime.time(10, 9, 3, 324392),
#  datetime.time(10, 39, 53, 481737),
#  datetime.time(11, 3, 25, 662789),
#  datetime.time(9, 22, 18, 661423),
#  datetime.time(10, 19, 58, 354583),
#  datetime.time(11, 11, 12, 227198),
#  datetime.time(10, 13, 1, 123783),
#  datetime.time(10, 17, 56, 166940),
#  datetime.time(11, 19, 5, 672300),
#  datetime.time(9, 5, 30, 740256),
#  datetime.time(9, 59, 50, 54417),
#  datetime.time(9, 24, 12, 325387),
#  datetime.time(10, 40, 51, 206049),
#  datetime.time(10, 28, 29, 333256),
#  datetime.time(10, 59, 43, 185927),
#  datetime.time(9, 6, 25, 364014),
#  datetime.time(9, 55, 54, 213217),
#  datetime.time(10, 28, 27, 156192),
#  datetime.time(11, 10, 47, 445410),
#  datetime.time(8, 1, 37, 452124),
#  datetime.time(9, 40, 22, 914097),
#  datetime.time(10, 39, 27, 396774),
#  datetime.time(9, 53, 22, 572568),
#  datetime.time(10, 42, 48, 695662),
#  datetime.time(11, 9, 17, 403990),
#  datetime.time(9, 10, 59, 825245),
#  datetime.time(11, 10, 34, 5206),
#  datetime.time(11, 38, 36, 296694),
#  datetime.time(10, 33, 35, 355537),
#  datetime.time(11, 43, 37, 324209),
#  datetime.time(9, 56, 11, 247673),
#  datetime.time(10, 30, 12, 641343),
#  datetime.time(10, 12, 3, 423463),
#  datetime.time(9, 34, 14, 524103),
#  datetime.time(12, 27, 37, 415090),
#  datetime.time(9, 29, 57, 77092),
#  datetime.time(10, 16, 26, 114416),
#  datetime.time(10, 7, 26, 157054),
#  datetime.time(9, 56, 56, 669557),
#  datetime.time(10, 36, 4, 140445),
#  datetime.time(9, 24, 9, 852980),
#  datetime.time(9, 36, 54, 469537),
#  datetime.time(9, 58, 33, 172265),
#  datetime.time(10, 25, 17, 532398),
#  datetime.time(9, 28, 34, 550447),
#  datetime.time(11, 44, 55, 749358),
#  datetime.time(11, 26, 8, 975747),
#  datetime.time(10, 48, 16, 30984),
#  datetime.time(11, 36, 16, 893205),
#  datetime.time(11, 59, 0, 811398),
#  datetime.time(10, 9, 15, 319552),
#  datetime.time(9, 49, 27, 395471),
#  datetime.time(11, 43, 55, 475451),
#  datetime.time(10, 46, 15, 965395),
#  datetime.time(10, 33, 35, 319163),
#  datetime.time(9, 2, 22, 165752),
#  datetime.time(10, 59, 52, 912163),
#  datetime.time(10, 18, 39, 599309),
#  datetime.time(9, 22, 31, 345161),
#  datetime.time(10, 42, 38, 194917),
#  datetime.time(9, 28, 26, 331104),
#  datetime.time(11, 8, 14, 839724),
#  datetime.time(9, 55, 36, 978703),
#  datetime.time(10, 48, 36, 887408),
#  datetime.time(10, 26, 50, 84973),
#  datetime.time(11, 5, 56, 268470),
#  datetime.time(8, 54, 11, 109090),
#  datetime.time(9, 48, 20, 178311),
#  datetime.time(11, 23, 8, 790441),
#  datetime.time(10, 38, 10, 814658),
#  datetime.time(10, 57, 56, 937112),
#  datetime.time(10, 42, 30, 864558),
#  datetime.time(10, 39, 51, 80523),
#  datetime.time(9, 54, 12, 707598),
#  datetime.time(11, 37, 0, 731696),
#  datetime.time(9, 3, 2, 579352),
#  datetime.time(9, 14, 33, 379739),
#  datetime.time(10, 18, 10, 111035),
#  datetime.time(9, 20, 54, 999185),
#  datetime.time(11, 32, 22, 240088),
#  datetime.time(10, 17, 4, 394315),
#  datetime.time(12, 22, 25, 307321),
#  datetime.time(10, 5, 56, 580503),
#  datetime.time(9, 46, 55, 796153),
#  datetime.time(12, 10, 14, 288697),
#  datetime.time(10, 59, 57, 942752),
#  datetime.time(10, 38, 32, 175928),
#  datetime.time(10, 26, 35, 558068),
#  datetime.time(9, 37, 56, 750036),
#  datetime.time(10, 6, 31, 885636),
#  datetime.time(9, 49, 33, 547519),
#  datetime.time(10, 5, 22, 552278),
#  datetime.time(11, 47, 30, 547033),
#  datetime.time(10, 57, 14, 528477),
#  datetime.time(9, 53, 41, 533439),
#  datetime.time(10, 0, 22, 104501),
#  datetime.time(10, 26, 26, 633649),
#  datetime.time(10, 10, 25, 246750),
#  datetime.time(10, 37, 10, 172386),
#  datetime.time(9, 45, 27, 417059),
#  datetime.time(9, 32, 46, 191708),
#  datetime.time(9, 36, 30, 711456),
#  datetime.time(10, 12, 33, 717647),
#  datetime.time(10, 51, 33, 477204),
#  datetime.time(11, 33, 34, 362887),
#  datetime.time(10, 21, 6, 169937),
#  datetime.time(9, 57, 51, 118960),
#  datetime.time(10, 49, 56, 8168),
#  datetime.time(9, 48, 40, 68317),
#  datetime.time(10, 13, 6, 58546),
#  datetime.time(10, 15, 48, 347571),
#  datetime.time(10, 43, 50, 634334),
#  datetime.time(10, 42, 19, 612775),
#  datetime.time(10, 5, 4, 171637),
#  datetime.time(11, 27, 1, 314045),
#  datetime.time(10, 10, 25, 192780),
#  datetime.time(10, 59, 31, 220723),
#  datetime.time(10, 17, 16, 619074),
#  datetime.time(11, 4, 5, 921985),
#  datetime.time(10, 33, 5, 312080),
#  datetime.time(9, 0, 41, 968457),
#  datetime.time(10, 39, 8, 409440),
#  datetime.time(9, 3, 12, 737693),
#  datetime.time(10, 16, 37, 104777),
#  datetime.time(11, 54, 10, 157872),
#  datetime.time(12, 33, 15, 122254),
#  datetime.time(10, 22, 13, 95545),
#  datetime.time(10, 47, 47, 501854),
#  datetime.time(12, 19, 19, 535022),
#  datetime.time(10, 23, 36, 274726),
#  datetime.time(9, 11, 22, 744784),
#  datetime.time(10, 11, 9, 995142),
#  datetime.time(10, 4, 31, 989543),
#  datetime.time(10, 9, 11, 206780),
#  datetime.time(10, 21, 24, 445494),
#  datetime.time(9, 57, 27, 604211),
#  datetime.time(10, 24, 8, 351626),
#  datetime.time(10, 12, 44, 83254),
#  datetime.time(10, 16, 15, 156432),
#  datetime.time(10, 44, 2, 516924),
#  datetime.time(10, 36, 19, 270698),
#  datetime.time(10, 34, 8, 155272),
#  datetime.time(8, 50, 11, 348858),
#  datetime.time(9, 55, 36, 492780),
#  datetime.time(9, 34, 14, 162620),
#  datetime.time(11, 31, 34, 200399),
#  datetime.time(9, 15, 34, 915475),
#  datetime.time(10, 41, 48, 935201),
#  datetime.time(10, 17, 42, 410733),
#  datetime.time(11, 28, 40, 530914),
#  datetime.time(10, 2, 3, 933113),
#  datetime.time(9, 16, 54, 306047),
#  datetime.time(9, 6, 17, 593082),
#  datetime.time(10, 16, 16, 362127),
#  datetime.time(9, 3, 46, 524276),
#  datetime.time(11, 22, 46, 724945),
#  datetime.time(9, 38, 18, 287599),
#  datetime.time(10, 56, 9, 973849),
#  datetime.time(10, 32, 57, 640585),
#  datetime.time(10, 53, 39, 845665),
#  datetime.time(10, 26, 53, 804388),
#  datetime.time(11, 8, 17, 790901),
#  datetime.time(10, 33, 23, 526072),
#  datetime.time(10, 55, 57, 893119),
#  datetime.time(9, 21, 51, 694968),
#  datetime.time(10, 57, 31, 398622),
#  datetime.time(11, 18, 2, 777947),
#  ...]

# %%
#Level 2 Charging 
depT=[]
for at,ct in zip(dfch['Commercial Morning Arrival'].values,dft['Level2 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(2,'Commercial Morning Departure Level 2',depT)

# %%
#Level 3 charging 
depT=[]
for at,ct in zip(dfch['Commercial Morning Arrival'].values,dft['Level3 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(3,'Commercial Morning Departure Level 3',depT)

# %% [markdown]
# Commercial Evening Departures

# %%
#Level1 charging 
depT=[]
for at,ct in zip(dfch['Commercial Evening Arrival'].values,dft['Level1 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(4,'Commercial Evening Departure Level 1',depT)

#Level 2 Charging 
depT=[]
for at,ct in zip(dfch['Commercial Evening Arrival'].values,dft['Level2 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(5,'Commercial Evening Departure Level 2',depT)

#Level 3 charging 
depT=[]
for at,ct in zip(dfch['Commercial Evening Arrival'].values,dft['Level3 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(6,'Commercial Evening Departure Level 3',depT)

# %% [markdown]
# Residential Evening charging time

# %%
#Level1 charging 
depT=[]
for at,ct in zip(dfch['Residential Evening Arrival'].values,dft['Level1 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(7,'Residential Evening Departure Level 1',depT)

#Level 2 Charging 
depT=[]
for at,ct in zip(dfch['Residential Evening Arrival'].values,dft['Level2 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(8,'Residential Evening Departure Level 2',depT)

#Level 3 charging 
depT=[]
for at,ct in zip(dfch['Residential Evening Arrival'].values,dft['Level3 Charging time'].values):
    temp=datetime.datetime.combine(datetime.date.today(),at)+datetime.timedelta(hours=ct)
    depT.append(temp.time())
dfch.insert(10,'Residential Departure Level 3',depT)

# %%
dfch
# Out:
#      Commercial Morning Arrival Commercial Morning Departure Level 1  \
# 0               08:44:33.989581                      09:39:38.326645
# 1               09:20:46.711759                      10:19:38.786829
# 2               09:05:10.705775                      09:56:31.880271
# 3               09:08:43.389945                      11:30:27.369153
# 4               08:56:23.582545                      10:41:05.356442
# ...                         ...                                  ...
# 8756            09:00:46.648383                      09:15:47.409853
# 8757            10:27:37.706630                      12:07:13.725103
# 8758            08:27:34.928088                      09:26:22.245107
# 8759            09:53:30.228494                      11:41:11.738338
# 8760            08:57:36.450042                      10:31:10.691098
#
#      Commercial Morning Departure Level 2  \
# 0                         08:49:43.771181
# 1                         09:26:17.843797
# 2                         09:09:59.565884
# 3                         09:22:00.637996
# 4                         09:06:12.498848
# ...                                   ...
# 8756                      09:02:11.094771
# 8757                      10:36:57.958362
# 8758                      08:33:05.614059
# 8759                      10:03:35.995042
# 8760                      09:06:22.785141
#
#      Commercial Morning Departure Level 3  \
# 0                         08:46:32.945715
# 1                         09:22:53.866462
# 2                         09:07:01.628057
# 3                         09:13:49.533196
# 4                         09:00:09.726405
# ...                                   ...
# 8756                      09:01:19.075796
# 8757                      10:31:12.843295
# 8758                      08:29:41.911501
# 8759                      09:57:22.842848
# 8760                      09:00:58.562720
#
#      Commercial Evening Departure Level 1  \
# 0                         17:39:06.422188
# 1                         16:21:18.376568
# 2                         14:44:19.028762
# 3                         18:26:45.967123
# 4                         16:54:46.820685
# ...                                   ...
# 8756                      15:07:27.060343
# 8757                      17:02:14.381379
# 8758                      16:49:48.878014
# 8759                      16:47:53.798809
# 8760                      16:53:42.121119
#
#      Commercial Evening Departure Level 2  \
# 0                         16:49:11.866724
# 1                         15:27:57.433536
# 2                         13:57:46.714375
# 3                         16:18:19.235966
# 4                         15:19:53.963091
# ...                                   ...
# 8756                      14:53:50.745261
# 8757                      15:31:58.614638
# 8758                      15:56:32.246966
# 8759                      15:10:18.055513
# 8760                      15:28:54.215162
#
#      Commercial Evening Departure Level 3  \
# 0                         16:46:01.041258
# 1                         15:24:33.456201
# 2                         13:54:48.776548
# 3                         16:10:08.131166
# 4                         15:13:51.190648
# ...                                   ...
# 8756                      14:52:58.726286
# 8757                      15:26:13.499571
# 8758                      15:53:08.544408
# 8759                      15:04:04.903319
# 8760                      15:23:29.992741
#
#      Residential Evening Departure Level 1  \
# 0                          14:29:42.225350
# 1                          14:18:17.455367
# 2                          15:20:45.499514
# 3                          16:14:06.790787
# 4                          15:33:54.214801
# ...                                    ...
# 8756                       14:30:16.139907
# 8757                       15:29:40.086455
# 8758                       14:33:18.290267
# 8759                       15:30:12.646588
# 8760                       14:37:04.862854
#
#      Residential Evening Departure Level 2 Commercial Evening Arrival  \
# 0                          13:39:47.669886            16:44:02.085124
# 1                          13:24:56.512335            15:22:26.301498
# 2                          14:34:13.185127            13:52:57.854266
# 3                          14:05:40.059630            16:05:01.987915
# 4                          13:59:01.357207            15:10:05.046788
# ...                                    ...                        ...
# 8756                       14:16:39.824825            14:52:26.298873
# 8757                       13:59:24.319714            15:22:38.362906
# 8758                       13:40:01.659219            15:51:01.560995
# 8759                       13:52:36.903292            15:00:12.288965
# 8760                       13:12:16.956897            15:20:07.880063
#
#      Residential Departure Level 3 Residential Evening Arrival  \
# 0                  13:36:36.844420             13:34:37.888286
# 1                  13:21:32.535000             13:19:25.380297
# 2                  14:31:15.247300             14:29:24.325018
# 3                  13:57:28.954830             13:52:22.811579
# 4                  13:52:58.584764             13:49:12.440904
# ...                            ...                         ...
# 8756               14:15:47.805850             14:15:15.378437
# 8757               13:53:39.204647             13:50:04.067982
# 8758               13:36:37.956661             13:34:30.973248
# 8759               13:46:23.751098             13:42:31.136744
# 8760               13:06:52.734476             13:03:30.621798
#
#       Travelled distance       soc  essCurKwh   distance  ChgEnergyReq
# 0              14.439188  0.702372   6.180875  14.428137      1.739125
# 1              15.893555  0.688751   6.061013  15.893021      1.858987
# 2              13.824990  0.715719   6.298329  13.824842      1.621671
# 3              40.344635  0.391389   3.444221  40.346598      4.475779
# 4              29.844284  0.524296   4.613803  29.847658      3.306197
# ...                  ...       ...        ...        ...           ...
# 8756            2.912245  0.846127   7.445915   2.907734      0.474085
# 8757           28.290413  0.542583   4.774727  28.290523      3.145273
# 8758           16.817493  0.689036   6.063517  16.817630      1.856483
# 8759           30.796301  0.513546   4.519205  30.796715      3.400795
# 8760           25.927843  0.564220   4.965136  25.924539      2.954864
#
# [8761 rows x 17 columns]

# %%
# Scatter plot between Plugin time and battery State of Charge 
sns.jointplot(data=dfch, x="Commercial Morning Arrival", y="soc", hue="species")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-d385349db48c> in <module>
#       1 # Scatter plot between Plugin time and battery State of Charge
# ----> 2 sns.jointplot(data=dfch, x="Commercial Morning Arrival", y="soc", hue="species")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2287
#    2288         joint_kws.setdefault("color", color)
# -> 2289         grid.plot_joint(plt.scatter, **joint_kws)
#    2290
#    2291         marginal_kws.setdefault("kde", False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_joint(self, func, **kwargs)
#    1775         """
#    1776         plt.sca(self.ax_joint)
# -> 1777         func(self.x, self.y, **kwargs)
#    1778
#    1779         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4441                 )
#    4442         collection.set_transform(mtransforms.IdentityTransform())
# -> 4443         collection.update(kwargs)
#    4444
#    4445         if colors is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'PathCollection' object has no property 'hue'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2098                            else suppress())
#    2099                     with ctx:
# -> 2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1733
#    1734             self.patch.draw(renderer)
# -> 1735             mimage._draw_list_compositing_images(
#    1736                 renderer, self, artists, self.suppressComposite)
#    1737
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1225         renderer.open_group(__name__, gid=self.get_gid())
#    1226
# -> 1227         ticks_to_draw = self._update_ticks()
#    1228         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1229                                                                 renderer)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1102         """
#    1103         major_locs = self.get_majorticklocs()
# -> 1104         major_labels = self.major.formatter.format_ticks(major_locs)
#    1105         major_ticks = self.get_major_ticks(len(major_locs))
#    1106         self.major.formatter.set_locs(major_locs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     254         """Return the tick labels for all the ticks at once."""
#     255         self.set_locs(values)
# --> 256         return [self(value, i) for i, value in enumerate(values)]
#     257
#     258     def format_data(self, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     254         """Return the tick labels for all the ticks at once."""
#     255         self.set_locs(values)
# --> 256         return [self(value, i) for i, value in enumerate(values)]
#     257
#     258     def format_data(self, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py in __call__(self, x, pos)
#     181             return pydt.time(h, m, s, msus).strftime(fmt)
#     182         elif ms != 0:
# --> 183             return pydt.time(h, m, s, msus).strftime(fmt)[:-3]
#     184         elif s != 0:
#     185             return pydt.time(h, m, s).strftime("%H:%M:%S")
#
# ValueError: microsecond must be in 0..999999

# %% [markdown]
# Charging Stretigies: 1. Uncontrolled Charging 2. Time delayed Charging 3.Smart Charging Based on Heuristic Algo
